# %%
import pandas as pd
import ast
import spacy
nlp = spacy.load("en_core_web_lg")

# %%
# Função para converter uma string para uma lista
def str_to_list(x):
    """
    Converte uma string em uma lista.

    Parâmetros:
    x (str): A string a ser convertida.

    Retorna:
    list: A lista resultante da conversão da string.
          Se a conversão falhar, retorna a string original.
    """
    try:
        return ast.literal_eval(x)
    except (SyntaxError, ValueError):
        return x
    
    # Função para substituir a máscara em uma string com um token específico
def substituir_prompt(sentence, token):
    return sentence.replace('[MASK]', token)

# Função para extrair tokens que são reconhecidos como entidades nomeadas
def extrair_tokens_gpe2(sentence, token_info, nlp):
    token = token_info['token']
    doc = nlp(substituir_prompt(sentence, token.capitalize()))
    #print(doc)
    for ent in doc.ents:
        print(ent)
        if str(ent).lower() == token.lower() and ent.label_ == 'GPE':
            return {'token': token.lower(), 'score': token_info['score']}
    return None

# Função para extrair tokens que são reconhecidos como entidades nomeadas
def extrair_tokens_org2(sentence, token_info, nlp):
    token = token_info['token']
    doc = nlp(substituir_prompt(sentence, token))
    #print(doc)
    for ent in doc.ents:
        if str(ent).lower() == token.lower() and ent.label_ == 'ORG':
            return {'token': token.lower(), 'score': token_info['score']}
    return None

# Função principal para aplicar extração de tokens em um DataFrame
def extrair_tokens_dataframe(dataframe, masked_columns, original_columns, nlp, extrator):
    # Inicializar um novo DataFrame para armazenar os tokens extraídos
    tokens_extraidos = {col: [] for col in original_columns}
    # Iterar sobre cada linha do DataFrame
    for _, row in dataframe.iterrows():
        for masked_col, original_col in zip(masked_columns, original_columns):
            tokens = []
            for token_info in row[original_col]:
                extracted_token = extrator(row[masked_col], token_info, nlp)
                if extracted_token:
                    tokens.append(extracted_token)
            tokens_extraidos[original_col].append(tokens)
    
    # Criar um novo DataFrame com os tokens extraídos
    tokens_dataframe = pd.DataFrame(tokens_extraidos)
    return tokens_dataframe

# %%
def mask_words_in_dataframe(df, columns, words_to_mask):
    """
    Substitui palavras específicas por '[MASK]' em colunas específicas de um DataFrame.
    
    :param df: DataFrame onde as palavras serão substituídas.
    :param columns: Lista de colunas onde as palavras serão substituídas.
    :param words_to_mask: Lista de palavras que serão substituídas por '[MASK]'. Deve ter o mesmo comprimento que o DataFrame.
    :return: DataFrame com as palavras substituídas por '[MASK]'.
    """
    df_copy = df.copy()  # Fazer uma cópia do DataFrame para evitar alterar o original
    for col, word in zip(columns, words_to_mask):
        df_copy[col] = df_copy[col].str.replace(word, '[MASK]', regex=False)
    return df_copy

# %% [markdown]
# # Spacy

# %% [markdown]
# ## Zero-Shot

# %% [markdown]
# ### Bert

# %%
prompt_bornIn = pd.read_csv('D:/tese/code/data/novos_data/dados/t5_bornIn.csv')
prompt_bornIn.drop(columns=['Unnamed: 0'], inplace=True)
bornIn_bert = pd.read_csv('D:/tese/code/data_v2/outputs/bert/outputs_bornIn_bert_v2.csv')
bornIn_bert.drop(columns=['Unnamed: 0'], inplace=True)
bornIn_bert = bornIn_bert.map(str_to_list)

prompt_diedIn = pd.read_csv('D:/tese/code/data/novos_data/dados/t5_diedIn.csv')
prompt_diedIn.drop(columns=['Unnamed: 0'], inplace=True)
diedIn_bert = pd.read_csv('D:/tese/code/data_v2/outputs/bert/outputs_diedIn_bert_v2.csv')
diedIn_bert.drop(columns=['Unnamed: 0'], inplace=True)
diedIn_bert = diedIn_bert.map(str_to_list)

prompt_capital = pd.read_csv('D:/tese/code/data/novos_data/dados/t5_capital.csv')
prompt_capital.drop(columns=['Unnamed: 0'], inplace=True)
capital_bert = pd.read_csv('D:/tese/code/data_v2/outputs/bert/outputs_capital_bert_v2.csv')
capital_bert.drop(columns=['Unnamed: 0'], inplace=True)
capital_bert = capital_bert.map(str_to_list)

prompt_citizen = pd.read_csv('D:/tese/code/data/novos_data/dados/t5_citizen.csv')
prompt_citizen.drop(columns=['Unnamed: 0'], inplace=True)
citizen_bert = pd.read_csv('D:/tese/code/data_v2/outputs/bert/outputs_citizen_bert_v2.csv')
citizen_bert.drop(columns=['Unnamed: 0'], inplace=True)
citizen_bert = citizen_bert.map(str_to_list)

prompt_worksfor = pd.read_csv('D:/tese/code/data/novos_data/dados/t5_worksfor.csv').iloc[:379]
prompt_worksfor.drop(columns=['Unnamed: 0'], inplace=True)
worksfor_bert = pd.read_csv('D:/tese/code/data_v2/outputs/bert/outputs_worksfor_bert_v2.csv')
worksfor_bert.drop(columns=['Unnamed: 0'], inplace=True)
worksfor_bert = worksfor_bert.map(str_to_list)

# %%
# Creating a new DataFrame from 'prompt' with specified columns
bornIn_bert_spacy = prompt_bornIn[['masked_sentence', 'T5_paraphrased_filled_sentence_0', 
               'T5_paraphrased_filled_sentence_1','T5_paraphrased_filled_sentence_2', 
               'T5_paraphrased_filled_sentence_3']].copy()

# Using .loc to avoid SettingWithCopyWarning
bornIn_bert_spacy.loc[:, 'original'] = bornIn_bert['original']
bornIn_bert_spacy.loc[:, 't5_0'] = bornIn_bert['t5_0']
bornIn_bert_spacy.loc[:, 't5_1'] = bornIn_bert['t5_1']
bornIn_bert_spacy.loc[:, 't5_2'] = bornIn_bert['t5_2']
bornIn_bert_spacy.loc[:, 't5_3'] = bornIn_bert['t5_3']
teste = bornIn_bert_spacy

# Creating a new DataFrame from 'prompt' with specified columns
diedIn_bert_spacy = prompt_diedIn[['masked_sentence', 'T5_paraphrased_filled_sentence_0', 
               'T5_paraphrased_filled_sentence_1','T5_paraphrased_filled_sentence_2', 
               'T5_paraphrased_filled_sentence_3']].copy()

# Using .loc to avoid SettingWithCopyWarning
diedIn_bert_spacy.loc[:, 'original'] = diedIn_bert['original']
diedIn_bert_spacy.loc[:, 't5_0'] = diedIn_bert['t5_0']
diedIn_bert_spacy.loc[:, 't5_1'] = diedIn_bert['t5_1']
diedIn_bert_spacy.loc[:, 't5_2'] = diedIn_bert['t5_2']
diedIn_bert_spacy.loc[:, 't5_3'] = diedIn_bert['t5_3']

# Creating a new DataFrame from 'prompt' with specified columns
capital_bert_spacy = prompt_capital[['masked_sentence', 'T5_paraphrased_filled_sentence_0', 
               'T5_paraphrased_filled_sentence_1','T5_paraphrased_filled_sentence_2', 
               'T5_paraphrased_filled_sentence_3']].copy()

# Using .loc to avoid SettingWithCopyWarning
capital_bert_spacy.loc[:, 'original'] = capital_bert['original']
capital_bert_spacy.loc[:, 't5_0'] = capital_bert['t5_0']
capital_bert_spacy.loc[:, 't5_1'] = capital_bert['t5_1']
capital_bert_spacy.loc[:, 't5_2'] = capital_bert['t5_2']
capital_bert_spacy.loc[:, 't5_3'] = capital_bert['t5_3']

# Creating a new DataFrame from 'prompt' with specified columns
citizen_bert_spacy = prompt_citizen[['masked_sentence', 'T5_paraphrased_filled_sentence_0', 
               'T5_paraphrased_filled_sentence_1','T5_paraphrased_filled_sentence_2', 
               'T5_paraphrased_filled_sentence_3']].copy()

# Using .loc to avoid SettingWithCopyWarning
citizen_bert_spacy.loc[:, 'original'] = citizen_bert['original']
citizen_bert_spacy.loc[:, 't5_0'] = citizen_bert['t5_0']
citizen_bert_spacy.loc[:, 't5_1'] = citizen_bert['t5_1']
citizen_bert_spacy.loc[:, 't5_2'] = citizen_bert['t5_2']
citizen_bert_spacy.loc[:, 't5_3'] = citizen_bert['t5_3']

# Creating a new DataFrame from 'prompt' with specified columns
worksfor_bert_spacy = prompt_worksfor[['masked_sentence', 'T5_paraphrased_filled_sentence_0', 
               'T5_paraphrased_filled_sentence_1','T5_paraphrased_filled_sentence_2', 
               'T5_paraphrased_filled_sentence_3']].copy()

# Using .loc to avoid SettingWithCopyWarning
worksfor_bert_spacy.loc[:, 'original'] = worksfor_bert['original']
worksfor_bert_spacy.loc[:, 't5_0'] = worksfor_bert['t5_0']
worksfor_bert_spacy.loc[:, 't5_1'] = worksfor_bert['t5_1']
worksfor_bert_spacy.loc[:, 't5_2'] = worksfor_bert['t5_2']
worksfor_bert_spacy.loc[:, 't5_3'] = worksfor_bert['t5_3']

# %%
# Exemplo de uso
# Supondo que temos um DataFrame `novo` com as colunas especificadas
masked_columns = [
    'masked_sentence', 
    'T5_paraphrased_filled_sentence_0', 
    'T5_paraphrased_filled_sentence_1',
    'T5_paraphrased_filled_sentence_2', 
    'T5_paraphrased_filled_sentence_3'
]

# As colunas que contêm os tokens originais
original_columns = [
    'original', 
    't5_0', 
    't5_1', 
    't5_2', 
    't5_3'
]

# Chamar a função para extrair tokens
bornIn_bert_spacy = extrair_tokens_dataframe(bornIn_bert_spacy[:10], masked_columns, original_columns, nlp, extrair_tokens_gpe2)
diedIn_bert_spacy = extrair_tokens_dataframe(diedIn_bert_spacy, masked_columns, original_columns, nlp, extrair_tokens_gpe2)
capital_bert_spacy = extrair_tokens_dataframe(capital_bert_spacy, masked_columns, original_columns, nlp, extrair_tokens_gpe2)
citizen_bert_spacy = extrair_tokens_dataframe(citizen_bert_spacy, masked_columns, original_columns, nlp, extrair_tokens_gpe2)
worksfor_bert_spacy = extrair_tokens_dataframe(worksfor_bert_spacy, masked_columns, original_columns, nlp, extrair_tokens_org2)

# %%
# Função para substituir a máscara em uma string com um token específico
def substituir_prompt(sentence, token):
    return sentence.replace('[MASK]', token)

# Função para extrair tokens que são reconhecidos como entidades nomeadas
def extrair_tokens_gpe2(sentence, token_info, nlp):
    token = token_info['token']
    doc = nlp(substituir_prompt(sentence, token))
    print(doc)
    for ent in doc.ents:
        if str(ent).lower() == token.lower() and ent.label_ == 'GPE':
            return {'token': token.lower(), 'score': token_info['score']}
    return None

# Função principal para aplicar extração de tokens em um DataFrame
def extrair_tokens_dataframe(dataframe, masked_columns, original_columns, nlp):
    # Inicializar um novo DataFrame para armazenar os tokens extraídos
    tokens_extraidos = {col: [] for col in original_columns}
    
    # Iterar sobre cada linha do DataFrame
    for _, row in dataframe.iterrows():
        for masked_col, original_col in zip(masked_columns, original_columns):
            tokens = []
            for token_info in row[original_col]:
                extracted_token = extrair_tokens_gpe2(row[masked_col], token_info, nlp)
                if extracted_token:
                    tokens.append(extracted_token)
            tokens_extraidos[original_col].append(tokens)
    
    # Criar um novo DataFrame com os tokens extraídos
    tokens_dataframe = pd.DataFrame(tokens_extraidos)
    
    return tokens_dataframe

# Exemplo de uso
# Supondo que temos um DataFrame `df` com as colunas especificadas
columns_to_process2 = [
    'masked_sentence', 
    'T5_paraphrased_filled_sentence_0', 
    'T5_paraphrased_filled_sentence_1',
    'T5_paraphrased_filled_sentence_2', 
    'T5_paraphrased_filled_sentence_3'
]

# As colunas que contêm os tokens originais
original_columns2 = [
    'original', 
    't5_0', 
    't5_1', 
    't5_2', 
    't5_3'
]

# Chamar a função para extrair tokens
bornIn_bert_spacy = extrair_tokens_dataframe(bornIn_bert_spacy[:10], columns_to_process2,original_columns2, nlp)

# Visualizar o resultado
display(bornIn_bert_spacy)
# Out:
# Allan Peiper (born 26 April 1960 in melbourne, Australia) is a former Professional cyclist, who competed in five Tour de France cycle races.
# Allan Peiper (born 26 April 1960 in sydney, Australia) is a former Professional cyclist, who competed in five Tour de France cycle races.
# Allan Peiper (born 26 April 1960 in brisbane, Australia) is a former Professional cyclist, who competed in five Tour de France cycle races.
# Allan Peiper (born 26 April 1960 in adelaide, Australia) is a former Professional cyclist, who competed in five Tour de France cycle races.
# Allan Peiper (born 26 April 1960 in perth, Australia) is a former Professional cyclist, who competed in five Tour de France cycle races.
# Allan Peiper (born 26 April 1960 in canberra, Australia) is a former Professional cyclist, who competed in five Tour de France cycle races.
# Allan Peiper (born 26 April 1960 in victoria, Australia) is a former Professional cyclist, who competed in five Tour de France cycle races.
# Allan Peiper (born 26 April 1960 in geelong, Australia) is a former Professional cyclist, who competed in five Tour de France cycle races.
# Allan Peiper (born 26 April 1960 in queensland, Australia) is a former Professional cyclist, who competed in five Tour de France cycle races.
# Allan Peiper (born 26 April 1960 in tasmania, Australia) is a former Professional cyclist, who competed in five Tour de France cycle races.
# Allan Peiper, a professional cyclist from Alexandra, Australia, was born on April 26, 1960, and has participated in five Tour de france cycle races.
# Allan Peiper, a professional cyclist from Alexandra, Australia, was born on April 26, 1960, and has participated in five Tour de korea cycle races.
# Allan Peiper, a professional cyclist from Alexandra, Australia, was born on April 26, 1960, and has participated in five Tour de taiwan cycle races.
# Allan Peiper, a professional cyclist from Alexandra, Australia, was born on April 26, 1960, and has participated in five Tour de paris cycle races.
# Allan Peiper, a professional cyclist from Alexandra, Australia, was born on April 26, 1960, and has participated in five Tour de luxembourg cycle races.
# Allan Peiper, a professional cyclist from Alexandra, Australia, was born on April 26, 1960, and has participated in five Tour de california cycle races.
# Allan Peiper, a professional cyclist from Alexandra, Australia, was born on April 26, 1960, and has participated in five Tour de yorkshire cycle races.
# Allan Peiper, a professional cyclist from Alexandra, Australia, was born on April 26, 1960, and has participated in five Tour de berlin cycle races.
# Allan Peiper, a professional cyclist from Alexandra, Australia, was born on April 26, 1960, and has participated in five Tour de hokkaido cycle races.
# Allan Peiper, a professional cyclist from Alexandra, Australia, was born on April 26, 1960, and has participated in five Tour de ski cycle races.
# Formerly a Professional cyclist, Allan Peiper (born April 26, 1960 in Alexandra, Australia) participated in five Tour de france cycle races.
# Formerly a Professional cyclist, Allan Peiper (born April 26, 1960 in Alexandra, Australia) participated in five Tour de korea cycle races.
# Formerly a Professional cyclist, Allan Peiper (born April 26, 1960 in Alexandra, Australia) participated in five Tour de taiwan cycle races.
# Formerly a Professional cyclist, Allan Peiper (born April 26, 1960 in Alexandra, Australia) participated in five Tour de yorkshire cycle races.
# Formerly a Professional cyclist, Allan Peiper (born April 26, 1960 in Alexandra, Australia) participated in five Tour de berlin cycle races.
# Formerly a Professional cyclist, Allan Peiper (born April 26, 1960 in Alexandra, Australia) participated in five Tour de paris cycle races.
# Formerly a Professional cyclist, Allan Peiper (born April 26, 1960 in Alexandra, Australia) participated in five Tour de california cycle races.
# Formerly a Professional cyclist, Allan Peiper (born April 26, 1960 in Alexandra, Australia) participated in five Tour de europe cycle races.
# Formerly a Professional cyclist, Allan Peiper (born April 26, 1960 in Alexandra, Australia) participated in five Tour de hokkaido cycle races.
# Formerly a Professional cyclist, Allan Peiper (born April 26, 1960 in Alexandra, Australia) participated in five Tour de germany cycle races.
# Allan Peiper, who was born in Alexandra, Australia on April 26, 1960, has competed in five Tour de france cycle races and is a former professional cyclist.
# Allan Peiper, who was born in Alexandra, Australia on April 26, 1960, has competed in five Tour de korea cycle races and is a former professional cyclist.
# Allan Peiper, who was born in Alexandra, Australia on April 26, 1960, has competed in five Tour de taiwan cycle races and is a former professional cyclist.
# Allan Peiper, who was born in Alexandra, Australia on April 26, 1960, has competed in five Tour de paris cycle races and is a former professional cyclist.
# Allan Peiper, who was born in Alexandra, Australia on April 26, 1960, has competed in five Tour de berlin cycle races and is a former professional cyclist.
# Allan Peiper, who was born in Alexandra, Australia on April 26, 1960, has competed in five Tour de yorkshire cycle races and is a former professional cyclist.
# Allan Peiper, who was born in Alexandra, Australia on April 26, 1960, has competed in five Tour de luxembourg cycle races and is a former professional cyclist.
# Allan Peiper, who was born in Alexandra, Australia on April 26, 1960, has competed in five Tour de california cycle races and is a former professional cyclist.
# Allan Peiper, who was born in Alexandra, Australia on April 26, 1960, has competed in five Tour de germany cycle races and is a former professional cyclist.
# Allan Peiper, who was born in Alexandra, Australia on April 26, 1960, has competed in five Tour de europe cycle races and is a former professional cyclist.
# A former professional cyclist, Allan Peiper, was born in Alexandra, Australia on 26 April 1960 and has competed for five Tour de france cycles.
# A former professional cyclist, Allan Peiper, was born in Alexandra, Australia on 26 April 1960 and has competed for five Tour de la cycles.
# A former professional cyclist, Allan Peiper, was born in Alexandra, Australia on 26 April 1960 and has competed for five Tour de paris cycles.
# A former professional cyclist, Allan Peiper, was born in Alexandra, Australia on 26 April 1960 and has competed for five Tour de yorkshire cycles.
# A former professional cyclist, Allan Peiper, was born in Alexandra, Australia on 26 April 1960 and has competed for five Tour de korea cycles.
# A former professional cyclist, Allan Peiper, was born in Alexandra, Australia on 26 April 1960 and has competed for five Tour de america cycles.
# A former professional cyclist, Allan Peiper, was born in Alexandra, Australia on 26 April 1960 and has competed for five Tour de europe cycles.
# A former professional cyclist, Allan Peiper, was born in Alexandra, Australia on 26 April 1960 and has competed for five Tour de berlin cycles.
# A former professional cyclist, Allan Peiper, was born in Alexandra, Australia on 26 April 1960 and has competed for five Tour de germany cycles.
# A former professional cyclist, Allan Peiper, was born in Alexandra, Australia on 26 April 1960 and has competed for five Tour de ski cycles.
# It was won by the Conservative candidate Anthony Barber, who returned after losing his own constituency in the 1964 General Election.
# It was won by the Conservative candidate Anthony Barber, who returned after losing his previous constituency in the 1964 General Election.
# It was won by the Conservative candidate Anthony Barber, who returned after losing his old constituency in the 1964 General Election.
# It was won by the Conservative candidate Anthony Barber, who returned after losing his former constituency in the 1964 General Election.
# It was won by the Conservative candidate Anthony Barber, who returned after losing his home constituency in the 1964 General Election.
# It was won by the Conservative candidate Anthony Barber, who returned after losing his original constituency in the 1964 General Election.
# It was won by the Conservative candidate Anthony Barber, who returned after losing his local constituency in the 1964 General Election.
# It was won by the Conservative candidate Anthony Barber, who returned after losing his parliamentary constituency in the 1964 General Election.
# It was won by the Conservative candidate Anthony Barber, who returned after losing his earlier constituency in the 1964 General Election.
# It was won by the Conservative candidate Anthony Barber, who returned after losing his constituency constituency in the 1964 General Election.
# After losing his own constituency in the 1964 General Election, Anthony Barber, a Conservative candidate, won it.
# After losing his old constituency in the 1964 General Election, Anthony Barber, a Conservative candidate, won it.
# After losing his former constituency in the 1964 General Election, Anthony Barber, a Conservative candidate, won it.
# After losing his parliamentary constituency in the 1964 General Election, Anthony Barber, a Conservative candidate, won it.
# After losing his previous constituency in the 1964 General Election, Anthony Barber, a Conservative candidate, won it.
# After losing his home constituency in the 1964 General Election, Anthony Barber, a Conservative candidate, won it.
# After losing his new constituency in the 1964 General Election, Anthony Barber, a Conservative candidate, won it.
# After losing his original constituency in the 1964 General Election, Anthony Barber, a Conservative candidate, won it.
# After losing his constituency constituency in the 1964 General Election, Anthony Barber, a Conservative candidate, won it.
# After losing his local constituency in the 1964 General Election, Anthony Barber, a Conservative candidate, won it.
# Anthony Barber, the Conservative candidate who lost his own constituency in the 1964 General Election, won it.
# Anthony Barber, the Conservative candidate who lost his old constituency in the 1964 General Election, won it.
# Anthony Barber, the Conservative candidate who lost his former constituency in the 1964 General Election, won it.
# Anthony Barber, the Conservative candidate who lost his home constituency in the 1964 General Election, won it.
# Anthony Barber, the Conservative candidate who lost his previous constituency in the 1964 General Election, won it.
# Anthony Barber, the Conservative candidate who lost his parliamentary constituency in the 1964 General Election, won it.
# Anthony Barber, the Conservative candidate who lost his constituency constituency in the 1964 General Election, won it.
# Anthony Barber, the Conservative candidate who lost his local constituency in the 1964 General Election, won it.
# Anthony Barber, the Conservative candidate who lost his birmingham constituency in the 1964 General Election, won it.
# Anthony Barber, the Conservative candidate who lost his original constituency in the 1964 General Election, won it.
# The Conservative candidate Anthony Barber, who had lost his own constituency in the 1964 General Election, won it.
# The Conservative candidate Anthony Barber, who had lost his parliamentary constituency in the 1964 General Election, won it.
# The Conservative candidate Anthony Barber, who had lost his previous constituency in the 1964 General Election, won it.
# The Conservative candidate Anthony Barber, who had lost his old constituency in the 1964 General Election, won it.
# The Conservative candidate Anthony Barber, who had lost his former constituency in the 1964 General Election, won it.
# The Conservative candidate Anthony Barber, who had lost his home constituency in the 1964 General Election, won it.
# The Conservative candidate Anthony Barber, who had lost his constituency constituency in the 1964 General Election, won it.
# The Conservative candidate Anthony Barber, who had lost his local constituency in the 1964 General Election, won it.
# The Conservative candidate Anthony Barber, who had lost his birmingham constituency in the 1964 General Election, won it.
# The Conservative candidate Anthony Barber, who had lost his original constituency in the 1964 General Election, won it.
# Following his defeat in the 1964 General Election, Anthony Barber of the Conservative Party won the election.
# Following his defeat in the 1964 General Election, Anthony Barber of the Conservative Party won the election.
# Following his defeat in the 1964 General Election, Anthony Barber of the Conservative Party won the election.
# Following his defeat in the 1964 General Election, Anthony Barber of the Conservative Party won the election.
# Following his defeat in the 1964 General Election, Anthony Barber of the Conservative Party won the election.
# Following his defeat in the 1964 General Election, Anthony Barber of the Conservative Party won the election.
# Following his defeat in the 1964 General Election, Anthony Barber of the Conservative Party won the election.
# Following his defeat in the 1964 General Election, Anthony Barber of the Conservative Party won the election.
# Following his defeat in the 1964 General Election, Anthony Barber of the Conservative Party won the election.
# Following his defeat in the 1964 General Election, Anthony Barber of the Conservative Party won the election.
# NahooToo is the second album by australian musician Paul Mounsey.
# NahooToo is the second album by canadian musician Paul Mounsey.
# NahooToo is the second album by american musician Paul Mounsey.
# NahooToo is the second album by folk musician Paul Mounsey.
# NahooToo is the second album by english musician Paul Mounsey.
# NahooToo is the second album by british musician Paul Mounsey.
# NahooToo is the second album by irish musician Paul Mounsey.
# NahooToo is the second album by scottish musician Paul Mounsey.
# NahooToo is the second album by welsh musician Paul Mounsey.
# NahooToo is the second album by jazz musician Paul Mounsey.
# Paul Mounsey, a musician from toronto, has released his second album, NahooToo.
# Paul Mounsey, a musician from london, has released his second album, NahooToo.
# Paul Mounsey, a musician from australia, has released his second album, NahooToo.
# Paul Mounsey, a musician from canada, has released his second album, NahooToo.
# Paul Mounsey, a musician from sydney, has released his second album, NahooToo.
# Paul Mounsey, a musician from melbourne, has released his second album, NahooToo.
# Paul Mounsey, a musician from england, has released his second album, NahooToo.
# Paul Mounsey, a musician from scotland, has released his second album, NahooToo.
# Paul Mounsey, a musician from jamaica, has released his second album, NahooToo.
# Paul Mounsey, a musician from montreal, has released his second album, NahooToo.
# The second album of Paul Mounsey's Scottish band, NahooToo, is released.
# The second album of Paul Mounsey's Scottish band, NahooToo, is released.
# The second album of Paul Mounsey's Scottish band, NahooToo, is released.
# The second album of Paul Mounsey's Scottish band, NahooToo, is released.
# The second album of Paul Mounsey's Scottish band, NahooToo, is released.
# The second album of Paul Mounsey's Scottish band, NahooToo, is released.
# The second album of Paul Mounsey's Scottish band, NahooToo, is released.
# The second album of Paul Mounsey's Scottish band, NahooToo, is released.
# The second album of Paul Mounsey's Scottish band, NahooToo, is released.
# The second album of Paul Mounsey's Scottish band, NahooToo, is released.
# NahooToo is the second album of Paul Mounsey, a musician hailing from australia.
# NahooToo is the second album of Paul Mounsey, a musician hailing from england.
# NahooToo is the second album of Paul Mounsey, a musician hailing from london.
# NahooToo is the second album of Paul Mounsey, a musician hailing from sydney.
# NahooToo is the second album of Paul Mounsey, a musician hailing from melbourne.
# NahooToo is the second album of Paul Mounsey, a musician hailing from scotland.
# NahooToo is the second album of Paul Mounsey, a musician hailing from ireland.
# NahooToo is the second album of Paul Mounsey, a musician hailing from jamaica.
# NahooToo is the second album of Paul Mounsey, a musician hailing from canada.
# NahooToo is the second album of Paul Mounsey, a musician hailing from toronto.
# australia's Paul Mounsey has released his second album Nahoon to the beat of.
# london's Paul Mounsey has released his second album Nahoon to the beat of.
# ireland's Paul Mounsey has released his second album Nahoon to the beat of.
# england's Paul Mounsey has released his second album Nahoon to the beat of.
# jamaica's Paul Mounsey has released his second album Nahoon to the beat of.
# canada's Paul Mounsey has released his second album Nahoon to the beat of.
# uk's Paul Mounsey has released his second album Nahoon to the beat of.
# scotland's Paul Mounsey has released his second album Nahoon to the beat of.
# reggae's Paul Mounsey has released his second album Nahoon to the beat of.
# liverpool's Paul Mounsey has released his second album Nahoon to the beat of.
# He has performed with many of jazz's foremost musicians including as a longstanding and charter member of Bernie Senensky's Moe Koffman Tribute Band.
# He has performed with many of america's foremost musicians including as a longstanding and charter member of Bernie Senensky's Moe Koffman Tribute Band.
# He has performed with many of canada's foremost musicians including as a longstanding and charter member of Bernie Senensky's Moe Koffman Tribute Band.
# He has performed with many of today's foremost musicians including as a longstanding and charter member of Bernie Senensky's Moe Koffman Tribute Band.
# He has performed with many of chicago's foremost musicians including as a longstanding and charter member of Bernie Senensky's Moe Koffman Tribute Band.
# He has performed with many of music's foremost musicians including as a longstanding and charter member of Bernie Senensky's Moe Koffman Tribute Band.
# He has performed with many of australia's foremost musicians including as a longstanding and charter member of Bernie Senensky's Moe Koffman Tribute Band.
# He has performed with many of nyc's foremost musicians including as a longstanding and charter member of Bernie Senensky's Moe Koffman Tribute Band.
# He has performed with many of country's foremost musicians including as a longstanding and charter member of Bernie Senensky's Moe Koffman Tribute Band.
# He has performed with many of europe's foremost musicians including as a longstanding and charter member of Bernie Senensky's Moe Koffman Tribute Band.
# Among the prominent musicians in chicago, he has been a member of Bernie Senensky's Moe Koffman Tribute Band for many years.
# Among the prominent musicians in jazz, he has been a member of Bernie Senensky's Moe Koffman Tribute Band for many years.
# Among the prominent musicians in philadelphia, he has been a member of Bernie Senensky's Moe Koffman Tribute Band for many years.
# Among the prominent musicians in nashville, he has been a member of Bernie Senensky's Moe Koffman Tribute Band for many years.
# Among the prominent musicians in pittsburgh, he has been a member of Bernie Senensky's Moe Koffman Tribute Band for many years.
# Among the prominent musicians in nyc, he has been a member of Bernie Senensky's Moe Koffman Tribute Band for many years.
# Among the prominent musicians in cleveland, he has been a member of Bernie Senensky's Moe Koffman Tribute Band for many years.
# Among the prominent musicians in seattle, he has been a member of Bernie Senensky's Moe Koffman Tribute Band for many years.
# Among the prominent musicians in concert, he has been a member of Bernie Senensky's Moe Koffman Tribute Band for many years.
# Among the prominent musicians in california, he has been a member of Bernie Senensky's Moe Koffman Tribute Band for many years.
# As a member of Bernie Senensky's Moe Koffman Tribute Band, he has been involved in the music industry for many years.
# As a member of Bernie Senensky's Moe Koffman Tribute Band, he has been involved in the music industry for many years.
# As a member of Bernie Senensky's Moe Koffman Tribute Band, he has been involved in the music industry for many years.
# As a member of Bernie Senensky's Moe Koffman Tribute Band, he has been involved in the music industry for many years.
# As a member of Bernie Senensky's Moe Koffman Tribute Band, he has been involved in the music industry for many years.
# As a member of Bernie Senensky's Moe Koffman Tribute Band, he has been involved in the music industry for many years.
# As a member of Bernie Senensky's Moe Koffman Tribute Band, he has been involved in the music industry for many years.
# As a member of Bernie Senensky's Moe Koffman Tribute Band, he has been involved in the music industry for many years.
# As a member of Bernie Senensky's Moe Koffman Tribute Band, he has been involved in the music industry for many years.
# As a member of Bernie Senensky's Moe Koffman Tribute Band, he has been involved in the music industry for many years.
# He has collaborated with a number of prominent musicians in jazz, including being formally affiliated with Bernie Senensky's Moe Koffman Tribute Band.
# He has collaborated with a number of prominent musicians in chicago, including being formally affiliated with Bernie Senensky's Moe Koffman Tribute Band.
# He has collaborated with a number of prominent musicians in music, including being formally affiliated with Bernie Senensky's Moe Koffman Tribute Band.
# He has collaborated with a number of prominent musicians in nashville, including being formally affiliated with Bernie Senensky's Moe Koffman Tribute Band.
# He has collaborated with a number of prominent musicians in europe, including being formally affiliated with Bernie Senensky's Moe Koffman Tribute Band.
# He has collaborated with a number of prominent musicians in canada, including being formally affiliated with Bernie Senensky's Moe Koffman Tribute Band.
# He has collaborated with a number of prominent musicians in america, including being formally affiliated with Bernie Senensky's Moe Koffman Tribute Band.
# He has collaborated with a number of prominent musicians in nyc, including being formally affiliated with Bernie Senensky's Moe Koffman Tribute Band.
# He has collaborated with a number of prominent musicians in hollywood, including being formally affiliated with Bernie Senensky's Moe Koffman Tribute Band.
# He has collaborated with a number of prominent musicians in japan, including being formally affiliated with Bernie Senensky's Moe Koffman Tribute Band.
# Many of jazz's top musicians have collaborated with him, and he has been a member of Bernie Senensky'S Moe Koffman Tribute Band for an extended period.
# Many of chicago's top musicians have collaborated with him, and he has been a member of Bernie Senensky'S Moe Koffman Tribute Band for an extended period.
# Many of america's top musicians have collaborated with him, and he has been a member of Bernie Senensky'S Moe Koffman Tribute Band for an extended period.
# Many of canada's top musicians have collaborated with him, and he has been a member of Bernie Senensky'S Moe Koffman Tribute Band for an extended period.
# Many of today's top musicians have collaborated with him, and he has been a member of Bernie Senensky'S Moe Koffman Tribute Band for an extended period.
# Many of nashville's top musicians have collaborated with him, and he has been a member of Bernie Senensky'S Moe Koffman Tribute Band for an extended period.
# Many of rock's top musicians have collaborated with him, and he has been a member of Bernie Senensky'S Moe Koffman Tribute Band for an extended period.
# Many of country's top musicians have collaborated with him, and he has been a member of Bernie Senensky'S Moe Koffman Tribute Band for an extended period.
# Many of hollywood's top musicians have collaborated with him, and he has been a member of Bernie Senensky'S Moe Koffman Tribute Band for an extended period.
# Many of seattle's top musicians have collaborated with him, and he has been a member of Bernie Senensky'S Moe Koffman Tribute Band for an extended period.
# Kurt Schwertsik (born 25 June 1935, vienna) is an Austrian contemporary composer.
# Kurt Schwertsik (born 25 June 1935, graz) is an Austrian contemporary composer.
# Kurt Schwertsik (born 25 June 1935, innsbruck) is an Austrian contemporary composer.
# Kurt Schwertsik (born 25 June 1935, salzburg) is an Austrian contemporary composer.
# Kurt Schwertsik (born 25 June 1935, munich) is an Austrian contemporary composer.
# Kurt Schwertsik (born 25 June 1935, austria) is an Austrian contemporary composer.
# Kurt Schwertsik (born 25 June 1935, wien) is an Austrian contemporary composer.
# Kurt Schwertsik (born 25 June 1935, budapest) is an Austrian contemporary composer.
# Kurt Schwertsik (born 25 June 1935, prague) is an Austrian contemporary composer.
# Kurt Schwertsik (born 25 June 1935, zagreb) is an Austrian contemporary composer.
# The Austrian contemporary composer Kurt Schwertsik was born in vienna on June 25, 1935.
# The Austrian contemporary composer Kurt Schwertsik was born in graz on June 25, 1935.
# The Austrian contemporary composer Kurt Schwertsik was born in innsbruck on June 25, 1935.
# The Austrian contemporary composer Kurt Schwertsik was born in salzburg on June 25, 1935.
# The Austrian contemporary composer Kurt Schwertsik was born in munich on June 25, 1935.
# The Austrian contemporary composer Kurt Schwertsik was born in wien on June 25, 1935.
# The Austrian contemporary composer Kurt Schwertsik was born in austria on June 25, 1935.
# The Austrian contemporary composer Kurt Schwertsik was born in budapest on June 25, 1935.
# The Austrian contemporary composer Kurt Schwertsik was born in brno on June 25, 1935.
# The Austrian contemporary composer Kurt Schwertsik was born in prague on June 25, 1935.
# Kurt Schwertsik, an Austrian composer born in vienna on June 25, 1935, is recognized as a contemporary.
# Kurt Schwertsik, an Austrian composer born in graz on June 25, 1935, is recognized as a contemporary.
# Kurt Schwertsik, an Austrian composer born in salzburg on June 25, 1935, is recognized as a contemporary.
# Kurt Schwertsik, an Austrian composer born in munich on June 25, 1935, is recognized as a contemporary.
# Kurt Schwertsik, an Austrian composer born in innsbruck on June 25, 1935, is recognized as a contemporary.
# Kurt Schwertsik, an Austrian composer born in austria on June 25, 1935, is recognized as a contemporary.
# Kurt Schwertsik, an Austrian composer born in budapest on June 25, 1935, is recognized as a contemporary.
# Kurt Schwertsik, an Austrian composer born in prague on June 25, 1935, is recognized as a contemporary.
# Kurt Schwertsik, an Austrian composer born in wien on June 25, 1935, is recognized as a contemporary.
# Kurt Schwertsik, an Austrian composer born in berlin on June 25, 1935, is recognized as a contemporary.
# An Austrian composer of the modern era, Kurt Schwertsik was born in vienna on June 25, 1935.
# An Austrian composer of the modern era, Kurt Schwertsik was born in graz on June 25, 1935.
# An Austrian composer of the modern era, Kurt Schwertsik was born in salzburg on June 25, 1935.
# An Austrian composer of the modern era, Kurt Schwertsik was born in innsbruck on June 25, 1935.
# An Austrian composer of the modern era, Kurt Schwertsik was born in munich on June 25, 1935.
# An Austrian composer of the modern era, Kurt Schwertsik was born in austria on June 25, 1935.
# An Austrian composer of the modern era, Kurt Schwertsik was born in wien on June 25, 1935.
# An Austrian composer of the modern era, Kurt Schwertsik was born in budapest on June 25, 1935.
# An Austrian composer of the modern era, Kurt Schwertsik was born in prague on June 25, 1935.
# An Austrian composer of the modern era, Kurt Schwertsik was born in berlin on June 25, 1935.
# A contemporary composer of Austrian origin, Kurt Schwertsik was born in vienna on June 25, 1935.
# A contemporary composer of Austrian origin, Kurt Schwertsik was born in munich on June 25, 1935.
# A contemporary composer of Austrian origin, Kurt Schwertsik was born in berlin on June 25, 1935.
# A contemporary composer of Austrian origin, Kurt Schwertsik was born in graz on June 25, 1935.
# A contemporary composer of Austrian origin, Kurt Schwertsik was born in prague on June 25, 1935.
# A contemporary composer of Austrian origin, Kurt Schwertsik was born in hamburg on June 25, 1935.
# A contemporary composer of Austrian origin, Kurt Schwertsik was born in cologne on June 25, 1935.
# A contemporary composer of Austrian origin, Kurt Schwertsik was born in salzburg on June 25, 1935.
# A contemporary composer of Austrian origin, Kurt Schwertsik was born in budapest on June 25, 1935.
# A contemporary composer of Austrian origin, Kurt Schwertsik was born in zurich on June 25, 1935.
# Claude Arrieu (born paris, November 30, 1903 - died Paris, March 7, 1990) was a prolific French composer.
# Claude Arrieu (born lyon, November 30, 1903 - died Paris, March 7, 1990) was a prolific French composer.
# Claude Arrieu (born marseille, November 30, 1903 - died Paris, March 7, 1990) was a prolific French composer.
# Claude Arrieu (born bordeaux, November 30, 1903 - died Paris, March 7, 1990) was a prolific French composer.
# Claude Arrieu (born versailles, November 30, 1903 - died Paris, March 7, 1990) was a prolific French composer.
# Claude Arrieu (born metz, November 30, 1903 - died Paris, March 7, 1990) was a prolific French composer.
# Claude Arrieu (born toulouse, November 30, 1903 - died Paris, March 7, 1990) was a prolific French composer.
# Claude Arrieu (born nantes, November 30, 1903 - died Paris, March 7, 1990) was a prolific French composer.
# Claude Arrieu (born nice, November 30, 1903 - died Paris, March 7, 1990) was a prolific French composer.
# Claude Arrieu (born nancy, November 30, 1903 - died Paris, March 7, 1990) was a prolific French composer.
# Claude Arrieu, who was born in paris on November 30, 1903 and passed away on March 7, 1990, is known for his prolific work as a French composer.
# Claude Arrieu, who was born in france on November 30, 1903 and passed away on March 7, 1990, is known for his prolific work as a French composer.
# Claude Arrieu, who was born in lyon on November 30, 1903 and passed away on March 7, 1990, is known for his prolific work as a French composer.
# Claude Arrieu, who was born in marseille on November 30, 1903 and passed away on March 7, 1990, is known for his prolific work as a French composer.
# Claude Arrieu, who was born in bordeaux on November 30, 1903 and passed away on March 7, 1990, is known for his prolific work as a French composer.
# Claude Arrieu, who was born in montreal on November 30, 1903 and passed away on March 7, 1990, is known for his prolific work as a French composer.
# Claude Arrieu, who was born in toulouse on November 30, 1903 and passed away on March 7, 1990, is known for his prolific work as a French composer.
# Claude Arrieu, who was born in nantes on November 30, 1903 and passed away on March 7, 1990, is known for his prolific work as a French composer.
# Claude Arrieu, who was born in versailles on November 30, 1903 and passed away on March 7, 1990, is known for his prolific work as a French composer.
# Claude Arrieu, who was born in metz on November 30, 1903 and passed away on March 7, 1990, is known for his prolific work as a French composer.
# The French composer Claude Arrieu, who was born in paris on November 30, 1903 and passed away on March 7, 1990, is known for his prolific work.
# The French composer Claude Arrieu, who was born in lyon on November 30, 1903 and passed away on March 7, 1990, is known for his prolific work.
# The French composer Claude Arrieu, who was born in marseille on November 30, 1903 and passed away on March 7, 1990, is known for his prolific work.
# The French composer Claude Arrieu, who was born in montreal on November 30, 1903 and passed away on March 7, 1990, is known for his prolific work.
# The French composer Claude Arrieu, who was born in france on November 30, 1903 and passed away on March 7, 1990, is known for his prolific work.
# The French composer Claude Arrieu, who was born in nice on November 30, 1903 and passed away on March 7, 1990, is known for his prolific work.
# The French composer Claude Arrieu, who was born in laval on November 30, 1903 and passed away on March 7, 1990, is known for his prolific work.
# The French composer Claude Arrieu, who was born in versailles on November 30, 1903 and passed away on March 7, 1990, is known for his prolific work.
# The French composer Claude Arrieu, who was born in toulouse on November 30, 1903 and passed away on March 7, 1990, is known for his prolific work.
# The French composer Claude Arrieu, who was born in nantes on November 30, 1903 and passed away on March 7, 1990, is known for his prolific work.
# montreal native Claude Arrieu (born November 30, 1903 - died March 7, 1990) was one of the most prolific French composers.
# quebec native Claude Arrieu (born November 30, 1903 - died March 7, 1990) was one of the most prolific French composers.
# paris native Claude Arrieu (born November 30, 1903 - died March 7, 1990) was one of the most prolific French composers.
# local native Claude Arrieu (born November 30, 1903 - died March 7, 1990) was one of the most prolific French composers.
# lyon native Claude Arrieu (born November 30, 1903 - died March 7, 1990) was one of the most prolific French composers.
# french native Claude Arrieu (born November 30, 1903 - died March 7, 1990) was one of the most prolific French composers.
# ottawa native Claude Arrieu (born November 30, 1903 - died March 7, 1990) was one of the most prolific French composers.
# laval native Claude Arrieu (born November 30, 1903 - died March 7, 1990) was one of the most prolific French composers.
# canton native Claude Arrieu (born November 30, 1903 - died March 7, 1990) was one of the most prolific French composers.
# france native Claude Arrieu (born November 30, 1903 - died March 7, 1990) was one of the most prolific French composers.
# A prolific French composer, Claude Arrieu (born paris on November 30, 1903 until his death on March 7, 1990) is well-known.
# A prolific French composer, Claude Arrieu (born bordeaux on November 30, 1903 until his death on March 7, 1990) is well-known.
# A prolific French composer, Claude Arrieu (born france on November 30, 1903 until his death on March 7, 1990) is well-known.
# A prolific French composer, Claude Arrieu (born here on November 30, 1903 until his death on March 7, 1990) is well-known.
# A prolific French composer, Claude Arrieu (born there on November 30, 1903 until his death on March 7, 1990) is well-known.
# A prolific French composer, Claude Arrieu (born versailles on November 30, 1903 until his death on March 7, 1990) is well-known.
# A prolific French composer, Claude Arrieu (born lyon on November 30, 1903 until his death on March 7, 1990) is well-known.
# A prolific French composer, Claude Arrieu (born marseille on November 30, 1903 until his death on March 7, 1990) is well-known.
# A prolific French composer, Claude Arrieu (born toulouse on November 30, 1903 until his death on March 7, 1990) is well-known.
# A prolific French composer, Claude Arrieu (born metz on November 30, 1903 until his death on March 7, 1990) is well-known.
# Ryo Kase (加瀬 亮 Kase Ryō, born November 9, 1974 in tokyo) is a Japanese actor.
# Ryo Kase (加瀬 亮 Kase Ryō, born November 9, 1974 in osaka) is a Japanese actor.
# Ryo Kase (加瀬 亮 Kase Ryō, born November 9, 1974 in kobe) is a Japanese actor.
# Ryo Kase (加瀬 亮 Kase Ryō, born November 9, 1974 in hokkaido) is a Japanese actor.
# Ryo Kase (加瀬 亮 Kase Ryō, born November 9, 1974 in kyoto) is a Japanese actor.
# Ryo Kase (加瀬 亮 Kase Ryō, born November 9, 1974 in yokohama) is a Japanese actor.
# Ryo Kase (加瀬 亮 Kase Ryō, born November 9, 1974 in chiba) is a Japanese actor.
# Ryo Kase (加瀬 亮 Kase Ryō, born November 9, 1974 in nagoya) is a Japanese actor.
# Ryo Kase (加瀬 亮 Kase Ryō, born November 9, 1974 in japan) is a Japanese actor.
# Ryo Kase (加瀬 亮 Kase Ryō, born November 9, 1974 in okinawa) is a Japanese actor.
# Born in tokyo on November 9, 1974, Ryo Kase is a Japanese actor.
# Born in osaka on November 9, 1974, Ryo Kase is a Japanese actor.
# Born in japan on November 9, 1974, Ryo Kase is a Japanese actor.
# Born in kyoto on November 9, 1974, Ryo Kase is a Japanese actor.
# Born in hokkaido on November 9, 1974, Ryo Kase is a Japanese actor.
# Born in yokohama on November 9, 1974, Ryo Kase is a Japanese actor.
# Born in kobe on November 9, 1974, Ryo Kase is a Japanese actor.
# Born in okinawa on November 9, 1974, Ryo Kase is a Japanese actor.
# Born in nagoya on November 9, 1974, Ryo Kase is a Japanese actor.
# Born in hiroshima on November 9, 1974, Ryo Kase is a Japanese actor.
# The actor Ryo Kase, born in tokyo on November 9, 1974, is known as "Kase Ry."
# The actor Ryo Kase, born in osaka on November 9, 1974, is known as "Kase Ry."
# The actor Ryo Kase, born in japan on November 9, 1974, is known as "Kase Ry."
# The actor Ryo Kase, born in kyoto on November 9, 1974, is known as "Kase Ry."
# The actor Ryo Kase, born in yokohama on November 9, 1974, is known as "Kase Ry."
# The actor Ryo Kase, born in kobe on November 9, 1974, is known as "Kase Ry."
# The actor Ryo Kase, born in fukuoka on November 9, 1974, is known as "Kase Ry."
# The actor Ryo Kase, born in seoul on November 9, 1974, is known as "Kase Ry."
# The actor Ryo Kase, born in nagoya on November 9, 1974, is known as "Kase Ry."
# The actor Ryo Kase, born in hokkaido on November 9, 1974, is known as "Kase Ry."
# Ryo Kase, born in tokyo on November 9, 1974, is a Japanese actor.
# Ryo Kase, born in osaka on November 9, 1974, is a Japanese actor.
# Ryo Kase, born in kyoto on November 9, 1974, is a Japanese actor.
# Ryo Kase, born in kobe on November 9, 1974, is a Japanese actor.
# Ryo Kase, born in yokohama on November 9, 1974, is a Japanese actor.
# Ryo Kase, born in hokkaido on November 9, 1974, is a Japanese actor.
# Ryo Kase, born in japan on November 9, 1974, is a Japanese actor.
# Ryo Kase, born in okinawa on November 9, 1974, is a Japanese actor.
# Ryo Kase, born in nagoya on November 9, 1974, is a Japanese actor.
# Ryo Kase, born in hiroshima on November 9, 1974, is a Japanese actor.
# Born on November 9, 1974 in tokyo, Ryo Kase (; Kasein Ry) is a Japanese actor.
# Born on November 9, 1974 in osaka, Ryo Kase (; Kasein Ry) is a Japanese actor.
# Born on November 9, 1974 in hokkaido, Ryo Kase (; Kasein Ry) is a Japanese actor.
# Born on November 9, 1974 in kyoto, Ryo Kase (; Kasein Ry) is a Japanese actor.
# Born on November 9, 1974 in kobe, Ryo Kase (; Kasein Ry) is a Japanese actor.
# Born on November 9, 1974 in yokohama, Ryo Kase (; Kasein Ry) is a Japanese actor.
# Born on November 9, 1974 in okinawa, Ryo Kase (; Kasein Ry) is a Japanese actor.
# Born on November 9, 1974 in nagoya, Ryo Kase (; Kasein Ry) is a Japanese actor.
# Born on November 9, 1974 in chiba, Ryo Kase (; Kasein Ry) is a Japanese actor.
# Born on November 9, 1974 in japan, Ryo Kase (; Kasein Ry) is a Japanese actor.
# 1228 – paris, March 26, 1258) "the guardian"[citation needed] of Holland, son of Floris IV, Count of Holland (1210–1234) and Matilda of Brabant (ca.
# 1228 – died, March 26, 1258) "the guardian"[citation needed] of Holland, son of Floris IV, Count of Holland (1210–1234) and Matilda of Brabant (ca.
# 1228 – amsterdam, March 26, 1258) "the guardian"[citation needed] of Holland, son of Floris IV, Count of Holland (1210–1234) and Matilda of Brabant (ca.
# 1228 – -, March 26, 1258) "the guardian"[citation needed] of Holland, son of Floris IV, Count of Holland (1210–1234) and Matilda of Brabant (ca.
# 1228 – holland, March 26, 1258) "the guardian"[citation needed] of Holland, son of Floris IV, Count of Holland (1210–1234) and Matilda of Brabant (ca.
# 1228 – hague, March 26, 1258) "the guardian"[citation needed] of Holland, son of Floris IV, Count of Holland (1210–1234) and Matilda of Brabant (ca.
# 1228 – brussels, March 26, 1258) "the guardian"[citation needed] of Holland, son of Floris IV, Count of Holland (1210–1234) and Matilda of Brabant (ca.
# 1228 – london, March 26, 1258) "the guardian"[citation needed] of Holland, son of Floris IV, Count of Holland (1210–1234) and Matilda of Brabant (ca.
# 1228 – ?, March 26, 1258) "the guardian"[citation needed] of Holland, son of Floris IV, Count of Holland (1210–1234) and Matilda of Brabant (ca.
# 1228 – ), March 26, 1258) "the guardian"[citation needed] of Holland, son of Floris IV, Count of Holland (1210–1234) and Matilda of Brabant (ca.
# Holland, the son of Floris IV, Count of Holland (1210–1234) and Matilda (ca.), was known as "the guardian" during the years 1228 to March 26, 1258, in flanders.
# Holland, the son of Floris IV, Count of Holland (1210–1234) and Matilda (ca.), was known as "the guardian" during the years 1228 to March 26, 1258, in england.
# Holland, the son of Floris IV, Count of Holland (1210–1234) and Matilda (ca.), was known as "the guardian" during the years 1228 to March 26, 1258, in holland.
# Holland, the son of Floris IV, Count of Holland (1210–1234) and Matilda (ca.), was known as "the guardian" during the years 1228 to March 26, 1258, in brussels.
# Holland, the son of Floris IV, Count of Holland (1210–1234) and Matilda (ca.), was known as "the guardian" during the years 1228 to March 26, 1258, in germany.
# Holland, the son of Floris IV, Count of Holland (1210–1234) and Matilda (ca.), was known as "the guardian" during the years 1228 to March 26, 1258, in france.
# Holland, the son of Floris IV, Count of Holland (1210–1234) and Matilda (ca.), was known as "the guardian" during the years 1228 to March 26, 1258, in utrecht.
# Holland, the son of Floris IV, Count of Holland (1210–1234) and Matilda (ca.), was known as "the guardian" during the years 1228 to March 26, 1258, in antwerp.
# Holland, the son of Floris IV, Count of Holland (1210–1234) and Matilda (ca.), was known as "the guardian" during the years 1228 to March 26, 1258, in paris.
# Holland, the son of Floris IV, Count of Holland (1210–1234) and Matilda (ca.), was known as "the guardian" during the years 1228 to March 26, 1258, in europe.
# "The protector" was the name given to Holland, who was also the daughter of Floris IV, Count of Holland (120-1210) and Matilda of Brabant (ca.) during the period of 1228 to March 26, 1258 in flanders.
# "The protector" was the name given to Holland, who was also the daughter of Floris IV, Count of Holland (120-1210) and Matilda of Brabant (ca.) during the period of 1228 to March 26, 1258 in holland.
# "The protector" was the name given to Holland, who was also the daughter of Floris IV, Count of Holland (120-1210) and Matilda of Brabant (ca.) during the period of 1228 to March 26, 1258 in england.
# "The protector" was the name given to Holland, who was also the daughter of Floris IV, Count of Holland (120-1210) and Matilda of Brabant (ca.) during the period of 1228 to March 26, 1258 in france.
# "The protector" was the name given to Holland, who was also the daughter of Floris IV, Count of Holland (120-1210) and Matilda of Brabant (ca.) during the period of 1228 to March 26, 1258 in germany.
# "The protector" was the name given to Holland, who was also the daughter of Floris IV, Count of Holland (120-1210) and Matilda of Brabant (ca.) during the period of 1228 to March 26, 1258 in brussels.
# "The protector" was the name given to Holland, who was also the daughter of Floris IV, Count of Holland (120-1210) and Matilda of Brabant (ca.) during the period of 1228 to March 26, 1258 in utrecht.
# "The protector" was the name given to Holland, who was also the daughter of Floris IV, Count of Holland (120-1210) and Matilda of Brabant (ca.) during the period of 1228 to March 26, 1258 in paris.
# "The protector" was the name given to Holland, who was also the daughter of Floris IV, Count of Holland (120-1210) and Matilda of Brabant (ca.) during the period of 1228 to March 26, 1258 in europe.
# "The protector" was the name given to Holland, who was also the daughter of Floris IV, Count of Holland (120-1210) and Matilda of Brabant (ca.) during the period of 1228 to March 26, 1258 in burgundy.
# During the years 1228 to March 26, 1248, in holland, Holland, who was the son of Floris IV, Count of Holland (120-1210) and Matilda of Brabant (ca.), was designated as "the guardian."
# During the years 1228 to March 26, 1248, in flanders, Holland, who was the son of Floris IV, Count of Holland (120-1210) and Matilda of Brabant (ca.), was designated as "the guardian."
# During the years 1228 to March 26, 1248, in utrecht, Holland, who was the son of Floris IV, Count of Holland (120-1210) and Matilda of Brabant (ca.), was designated as "the guardian."
# During the years 1228 to March 26, 1248, in addition, Holland, who was the son of Floris IV, Count of Holland (120-1210) and Matilda of Brabant (ca.), was designated as "the guardian."
# During the years 1228 to March 26, 1248, in particular, Holland, who was the son of Floris IV, Count of Holland (120-1210) and Matilda of Brabant (ca.), was designated as "the guardian."
# During the years 1228 to March 26, 1248, in amsterdam, Holland, who was the son of Floris IV, Count of Holland (120-1210) and Matilda of Brabant (ca.), was designated as "the guardian."
# During the years 1228 to March 26, 1248, in fact, Holland, who was the son of Floris IV, Count of Holland (120-1210) and Matilda of Brabant (ca.), was designated as "the guardian."
# During the years 1228 to March 26, 1248, in antwerp, Holland, who was the son of Floris IV, Count of Holland (120-1210) and Matilda of Brabant (ca.), was designated as "the guardian."
# During the years 1228 to March 26, 1248, in brussels, Holland, who was the son of Floris IV, Count of Holland (120-1210) and Matilda of Brabant (ca.), was designated as "the guardian."
# During the years 1228 to March 26, 1248, in england, Holland, who was the son of Floris IV, Count of Holland (120-1210) and Matilda of Brabant (ca.), was designated as "the guardian."
# The guardian of Holland, who was the son and daughter of Floris IV, Count of Netherlands, and Matilda of Brabant, was mentioned in court from 1228 to March 26, 1258, under the title "Guardians."
# The guardian of Holland, who was the son and daughter of Floris IV, Count of Netherlands, and Matilda of Brabant, was mentioned in court from 1228 to March 26, 1258, under the title "Guardians."
# The guardian of Holland, who was the son and daughter of Floris IV, Count of Netherlands, and Matilda of Brabant, was mentioned in court from 1228 to March 26, 1258, under the title "Guardians."
# The guardian of Holland, who was the son and daughter of Floris IV, Count of Netherlands, and Matilda of Brabant, was mentioned in court from 1228 to March 26, 1258, under the title "Guardians."
# The guardian of Holland, who was the son and daughter of Floris IV, Count of Netherlands, and Matilda of Brabant, was mentioned in court from 1228 to March 26, 1258, under the title "Guardians."
# The guardian of Holland, who was the son and daughter of Floris IV, Count of Netherlands, and Matilda of Brabant, was mentioned in court from 1228 to March 26, 1258, under the title "Guardians."
# The guardian of Holland, who was the son and daughter of Floris IV, Count of Netherlands, and Matilda of Brabant, was mentioned in court from 1228 to March 26, 1258, under the title "Guardians."
# The guardian of Holland, who was the son and daughter of Floris IV, Count of Netherlands, and Matilda of Brabant, was mentioned in court from 1228 to March 26, 1258, under the title "Guardians."
# The guardian of Holland, who was the son and daughter of Floris IV, Count of Netherlands, and Matilda of Brabant, was mentioned in court from 1228 to March 26, 1258, under the title "Guardians."
# The guardian of Holland, who was the son and daughter of Floris IV, Count of Netherlands, and Matilda of Brabant, was mentioned in court from 1228 to March 26, 1258, under the title "Guardians."
# Henry Heras (11 September 1888, madrid - 14 December 1955, Bombay, India) was a Spanish Jesuit priest, archeologist and historian in India.
# Henry Heras (11 September 1888, barcelona - 14 December 1955, Bombay, India) was a Spanish Jesuit priest, archeologist and historian in India.
# Henry Heras (11 September 1888, spain - 14 December 1955, Bombay, India) was a Spanish Jesuit priest, archeologist and historian in India.
# Henry Heras (11 September 1888, seville - 14 December 1955, Bombay, India) was a Spanish Jesuit priest, archeologist and historian in India.
# Henry Heras (11 September 1888, bilbao - 14 December 1955, Bombay, India) was a Spanish Jesuit priest, archeologist and historian in India.
# Henry Heras (11 September 1888, salamanca - 14 December 1955, Bombay, India) was a Spanish Jesuit priest, archeologist and historian in India.
# Henry Heras (11 September 1888, toledo - 14 December 1955, Bombay, India) was a Spanish Jesuit priest, archeologist and historian in India.
# Henry Heras (11 September 1888, zaragoza - 14 December 1955, Bombay, India) was a Spanish Jesuit priest, archeologist and historian in India.
# Henry Heras (11 September 1888, valencia - 14 December 1955, Bombay, India) was a Spanish Jesuit priest, archeologist and historian in India.
# Henry Heras (11 September 1888, cadiz - 14 December 1955, Bombay, India) was a Spanish Jesuit priest, archeologist and historian in India.
# In Barcelona, Henry Heras was a Spanish Jesuit priest, archeologist, and historian who lived from 1896 until his death in 1955.
# In Barcelona, Henry Heras was a Spanish Jesuit priest, archeologist, and historian who lived from 1900 until his death in 1955.
# In Barcelona, Henry Heras was a Spanish Jesuit priest, archeologist, and historian who lived from 1891 until his death in 1955.
# In Barcelona, Henry Heras was a Spanish Jesuit priest, archeologist, and historian who lived from 1892 until his death in 1955.
# In Barcelona, Henry Heras was a Spanish Jesuit priest, archeologist, and historian who lived from 1888 until his death in 1955.
# In Barcelona, Henry Heras was a Spanish Jesuit priest, archeologist, and historian who lived from 1884 until his death in 1955.
# In Barcelona, Henry Heras was a Spanish Jesuit priest, archeologist, and historian who lived from 1898 until his death in 1955.
# In Barcelona, Henry Heras was a Spanish Jesuit priest, archeologist, and historian who lived from 1902 until his death in 1955.
# In Barcelona, Henry Heras was a Spanish Jesuit priest, archeologist, and historian who lived from 1899 until his death in 1955.
# In Barcelona, Henry Heras was a Spanish Jesuit priest, archeologist, and historian who lived from 1894 until his death in 1955.
# A Spanish Jesuit priest, archeologist, and historian from Barcelona lived in Bombay, india, before his death in 1955.
# A Spanish Jesuit priest, archeologist, and historian from Barcelona lived in Bombay, maharashtra, before his death in 1955.
# A Spanish Jesuit priest, archeologist, and historian from Barcelona lived in Bombay, bombay, before his death in 1955.
# A Spanish Jesuit priest, archeologist, and historian from Barcelona lived in Bombay, mumbai, before his death in 1955.
# A Spanish Jesuit priest, archeologist, and historian from Barcelona lived in Bombay, gujarat, before his death in 1955.
# A Spanish Jesuit priest, archeologist, and historian from Barcelona lived in Bombay, pakistan, before his death in 1955.
# A Spanish Jesuit priest, archeologist, and historian from Barcelona lived in Bombay, indian, before his death in 1955.
# A Spanish Jesuit priest, archeologist, and historian from Barcelona lived in Bombay, asia, before his death in 1955.
# A Spanish Jesuit priest, archeologist, and historian from Barcelona lived in Bombay, england, before his death in 1955.
# A Spanish Jesuit priest, archeologist, and historian from Barcelona lived in Bombay, california, before his death in 1955.
# Henry Heras, a Spanish Jesuit priest, archeologist, and historian in Barcelona, passed away on September 11, 1888, in barcelona before his death in Bombay.
# Henry Heras, a Spanish Jesuit priest, archeologist, and historian in Barcelona, passed away on September 11, 1888, in paris before his death in Bombay.
# Henry Heras, a Spanish Jesuit priest, archeologist, and historian in Barcelona, passed away on September 11, 1888, in madrid before his death in Bombay.
# Henry Heras, a Spanish Jesuit priest, archeologist, and historian in Barcelona, passed away on September 11, 1888, in goa before his death in Bombay.
# Henry Heras, a Spanish Jesuit priest, archeologist, and historian in Barcelona, passed away on September 11, 1888, in spain before his death in Bombay.
# Henry Heras, a Spanish Jesuit priest, archeologist, and historian in Barcelona, passed away on September 11, 1888, in rome before his death in Bombay.
# Henry Heras, a Spanish Jesuit priest, archeologist, and historian in Barcelona, passed away on September 11, 1888, in lisbon before his death in Bombay.
# Henry Heras, a Spanish Jesuit priest, archeologist, and historian in Barcelona, passed away on September 11, 1888, in manila before his death in Bombay.
# Henry Heras, a Spanish Jesuit priest, archeologist, and historian in Barcelona, passed away on September 11, 1888, in london before his death in Bombay.
# Henry Heras, a Spanish Jesuit priest, archeologist, and historian in Barcelona, passed away on September 11, 1888, in zaragoza before his death in Bombay.
# During his time in spain, Henry Heras worked as a Spanish Jesuit priest and archeologist before becoming renowned in the field of history.
# During his time in mexico, Henry Heras worked as a Spanish Jesuit priest and archeologist before becoming renowned in the field of history.
# During his time in peru, Henry Heras worked as a Spanish Jesuit priest and archeologist before becoming renowned in the field of history.
# During his time in europe, Henry Heras worked as a Spanish Jesuit priest and archeologist before becoming renowned in the field of history.
# During his time in madrid, Henry Heras worked as a Spanish Jesuit priest and archeologist before becoming renowned in the field of history.
# During his time in brazil, Henry Heras worked as a Spanish Jesuit priest and archeologist before becoming renowned in the field of history.
# During his time in cuba, Henry Heras worked as a Spanish Jesuit priest and archeologist before becoming renowned in the field of history.
# During his time in america, Henry Heras worked as a Spanish Jesuit priest and archeologist before becoming renowned in the field of history.
# During his time in rome, Henry Heras worked as a Spanish Jesuit priest and archeologist before becoming renowned in the field of history.
# During his time in france, Henry Heras worked as a Spanish Jesuit priest and archeologist before becoming renowned in the field of history.
# Daniele Franceschini (born 13 January 1976 in rome) is an Italian football midfielder.
# Daniele Franceschini (born 13 January 1976 in milan) is an Italian football midfielder.
# Daniele Franceschini (born 13 January 1976 in naples) is an Italian football midfielder.
# Daniele Franceschini (born 13 January 1976 in genoa) is an Italian football midfielder.
# Daniele Franceschini (born 13 January 1976 in florence) is an Italian football midfielder.
# Daniele Franceschini (born 13 January 1976 in bologna) is an Italian football midfielder.
# Daniele Franceschini (born 13 January 1976 in turin) is an Italian football midfielder.
# Daniele Franceschini (born 13 January 1976 in verona) is an Italian football midfielder.
# Daniele Franceschini (born 13 January 1976 in bari) is an Italian football midfielder.
# Daniele Franceschini (born 13 January 1976 in palermo) is an Italian football midfielder.
# Daniele Franceschini, an Italian football midfielder, was born in rome on 13 January 1976.
# Daniele Franceschini, an Italian football midfielder, was born in milan on 13 January 1976.
# Daniele Franceschini, an Italian football midfielder, was born in genoa on 13 January 1976.
# Daniele Franceschini, an Italian football midfielder, was born in naples on 13 January 1976.
# Daniele Franceschini, an Italian football midfielder, was born in florence on 13 January 1976.
# Daniele Franceschini, an Italian football midfielder, was born in turin on 13 January 1976.
# Daniele Franceschini, an Italian football midfielder, was born in bologna on 13 January 1976.
# Daniele Franceschini, an Italian football midfielder, was born in verona on 13 January 1976.
# Daniele Franceschini, an Italian football midfielder, was born in bari on 13 January 1976.
# Daniele Franceschini, an Italian football midfielder, was born in palermo on 13 January 1976.
# The Italian football midfielder Daniele Franceschini was born in rome on 13 January 1976.
# The Italian football midfielder Daniele Franceschini was born in milan on 13 January 1976.
# The Italian football midfielder Daniele Franceschini was born in verona on 13 January 1976.
# The Italian football midfielder Daniele Franceschini was born in florence on 13 January 1976.
# The Italian football midfielder Daniele Franceschini was born in genoa on 13 January 1976.
# The Italian football midfielder Daniele Franceschini was born in parma on 13 January 1976.
# The Italian football midfielder Daniele Franceschini was born in bari on 13 January 1976.
# The Italian football midfielder Daniele Franceschini was born in naples on 13 January 1976.
# The Italian football midfielder Daniele Franceschini was born in turin on 13 January 1976.
# The Italian football midfielder Daniele Franceschini was born in bologna on 13 January 1976.
# Born in rome on January 13, 1976, Daniele Franceschini is an Italian football midfielder.
# Born in milan on January 13, 1976, Daniele Franceschini is an Italian football midfielder.
# Born in genoa on January 13, 1976, Daniele Franceschini is an Italian football midfielder.
# Born in naples on January 13, 1976, Daniele Franceschini is an Italian football midfielder.
# Born in turin on January 13, 1976, Daniele Franceschini is an Italian football midfielder.
# Born in florence on January 13, 1976, Daniele Franceschini is an Italian football midfielder.
# Born in bologna on January 13, 1976, Daniele Franceschini is an Italian football midfielder.
# Born in palermo on January 13, 1976, Daniele Franceschini is an Italian football midfielder.
# Born in parma on January 13, 1976, Daniele Franceschini is an Italian football midfielder.
# Born in verona on January 13, 1976, Daniele Franceschini is an Italian football midfielder.
# An Italian football player, Daniele Franceschini, was born in rome on January 13, 1976, and is known for his exceptional abilities as a midfielder.
# An Italian football player, Daniele Franceschini, was born in milan on January 13, 1976, and is known for his exceptional abilities as a midfielder.
# An Italian football player, Daniele Franceschini, was born in turin on January 13, 1976, and is known for his exceptional abilities as a midfielder.
# An Italian football player, Daniele Franceschini, was born in italy on January 13, 1976, and is known for his exceptional abilities as a midfielder.
# An Italian football player, Daniele Franceschini, was born in genoa on January 13, 1976, and is known for his exceptional abilities as a midfielder.
# An Italian football player, Daniele Franceschini, was born in naples on January 13, 1976, and is known for his exceptional abilities as a midfielder.
# An Italian football player, Daniele Franceschini, was born in palermo on January 13, 1976, and is known for his exceptional abilities as a midfielder.
# An Italian football player, Daniele Franceschini, was born in bologna on January 13, 1976, and is known for his exceptional abilities as a midfielder.
# An Italian football player, Daniele Franceschini, was born in florence on January 13, 1976, and is known for his exceptional abilities as a midfielder.
# An Italian football player, Daniele Franceschini, was born in verona on January 13, 1976, and is known for his exceptional abilities as a midfielder.
#                                             original  \
# 0  [{'token': 'melbourne', 'score': 0.439}, {'tok...
# 1                                                 []
# 2                                                 []
# 3  [{'token': 'america', 'score': 0.28}, {'token'...
# 4  [{'token': 'vienna', 'score': 0.831}, {'token'...
# 5  [{'token': 'paris', 'score': 0.685}, {'token':...
# 6  [{'token': 'tokyo', 'score': 0.787}, {'token':...
# 7  [{'token': 'paris', 'score': 0.057}, {'token':...
# 8  [{'token': 'madrid', 'score': 0.496}, {'token'...
# 9  [{'token': 'rome', 'score': 0.335}, {'token': ...
#
#                                                 t5_0  \
# 0                                                 []
# 1                                                 []
# 2  [{'token': 'toronto', 'score': 0.035}, {'token...
# 3  [{'token': 'chicago', 'score': 0.152}, {'token...
# 4  [{'token': 'vienna', 'score': 0.513}, {'token'...
# 5  [{'token': 'paris', 'score': 0.71}, {'token': ...
# 6  [{'token': 'tokyo', 'score': 0.797}, {'token':...
# 7  [{'token': 'england', 'score': 0.1}, {'token':...
# 8                                                 []
# 9  [{'token': 'rome', 'score': 0.177}, {'token': ...
#
#                                                 t5_1  \
# 0                                                 []
# 1          [{'token': 'birmingham', 'score': 0.008}]
# 2                                                 []
# 3                                                 []
# 4  [{'token': 'vienna', 'score': 0.813}, {'token'...
# 5  [{'token': 'paris', 'score': 0.342}, {'token':...
# 6  [{'token': 'tokyo', 'score': 0.544}, {'token':...
# 7  [{'token': 'holland', 'score': 0.285}, {'token...
# 8  [{'token': 'india', 'score': 0.998}, {'token':...
# 9  [{'token': 'rome', 'score': 0.171}, {'token': ...
#
#                                                 t5_2  \
# 0                                                 []
# 1          [{'token': 'birmingham', 'score': 0.009}]
# 2  [{'token': 'australia', 'score': 0.097}, {'tok...
# 3  [{'token': 'chicago', 'score': 0.052}, {'token...
# 4  [{'token': 'vienna', 'score': 0.857}, {'token'...
# 5  [{'token': 'montreal', 'score': 0.147}, {'toke...
# 6  [{'token': 'tokyo', 'score': 0.763}, {'token':...
# 7  [{'token': 'holland', 'score': 0.118}, {'token...
# 8  [{'token': 'barcelona', 'score': 0.309}, {'tok...
# 9  [{'token': 'rome', 'score': 0.246}, {'token': ...
#
#                                                 t5_3
# 0                                                 []
# 1                                                 []
# 2  [{'token': 'australia', 'score': 0.049}, {'tok...
# 3  [{'token': 'chicago', 'score': 0.117}, {'token...
# 4  [{'token': 'vienna', 'score': 0.517}, {'token'...
# 5  [{'token': 'paris', 'score': 0.685}, {'token':...
# 6  [{'token': 'tokyo', 'score': 0.778}, {'token':...
# 7                                                 []
# 8  [{'token': 'spain', 'score': 0.312}, {'token':...
# 9  [{'token': 'rome', 'score': 0.224}, {'token': ...

# %% [markdown]
# ### Roberta

# %%
bornIn_roberta = pd.read_csv('D:/tese/code/data_v2/outputs/roberta/outputs_bornIn_roberta_v2.csv')
bornIn_roberta.drop(columns=['Unnamed: 0'], inplace=True)
bornIn_roberta = bornIn_roberta.map(str_to_list)


diedIn_roberta = pd.read_csv('D:/tese/code/data_v2/outputs/roberta/outputs_diedIn_roberta_v2.csv')
diedIn_roberta.drop(columns=['Unnamed: 0'], inplace=True)
diedIn_roberta = diedIn_roberta.map(str_to_list)


capital_roberta = pd.read_csv('D:/tese/code/data_v2/outputs/roberta/outputs_capital_roberta_v2.csv')
capital_roberta.drop(columns=['Unnamed: 0'], inplace=True)
capital_roberta = capital_roberta.map(str_to_list)


citizen_roberta = pd.read_csv('D:/tese/code/data_v2/outputs/roberta/outputs_citizen_roberta_v2.csv')
citizen_roberta.drop(columns=['Unnamed: 0'], inplace=True)
citizen_roberta = citizen_roberta.map(str_to_list)


worksfor_roberta = pd.read_csv('D:/tese/code/data_v2/outputs/roberta/outputs_worksfor_roberta_v2.csv')
worksfor_roberta.drop(columns=['Unnamed: 0'], inplace=True)
worksfor_roberta = worksfor_roberta.map(str_to_list)

# %%
# Creating a new DataFrame from 'prompt' with specified columns
bornIn_roberta_spacy = prompt_bornIn[['masked_sentence', 'T5_paraphrased_filled_sentence_0', 
               'T5_paraphrased_filled_sentence_1','T5_paraphrased_filled_sentence_2', 
               'T5_paraphrased_filled_sentence_3']].copy()

# Using .loc to avoid SettingWithCopyWarning
bornIn_roberta_spacy.loc[:, 'original'] = bornIn_roberta['original']
bornIn_roberta_spacy.loc[:, 't5_0'] = bornIn_roberta['t5_0']
bornIn_roberta_spacy.loc[:, 't5_1'] = bornIn_roberta['t5_1']
bornIn_roberta_spacy.loc[:, 't5_2'] = bornIn_roberta['t5_2']
bornIn_roberta_spacy.loc[:, 't5_3'] = bornIn_roberta['t5_3']

# Creating a new DataFrame from 'prompt' with specified columns
diedIn_roberta_spacy = prompt_diedIn[['masked_sentence', 'T5_paraphrased_filled_sentence_0', 
               'T5_paraphrased_filled_sentence_1','T5_paraphrased_filled_sentence_2', 
               'T5_paraphrased_filled_sentence_3']].copy()

# Using .loc to avoid SettingWithCopyWarning
diedIn_roberta_spacy.loc[:, 'original'] = diedIn_roberta['original']
diedIn_roberta_spacy.loc[:, 't5_0'] = diedIn_roberta['t5_0']
diedIn_roberta_spacy.loc[:, 't5_1'] = diedIn_roberta['t5_1']
diedIn_roberta_spacy.loc[:, 't5_2'] = diedIn_roberta['t5_2']
diedIn_roberta_spacy.loc[:, 't5_3'] = diedIn_roberta['t5_3']

# Creating a new DataFrame from 'prompt' with specified columns
capital_roberta_spacy = prompt_capital[['masked_sentence', 'T5_paraphrased_filled_sentence_0', 
               'T5_paraphrased_filled_sentence_1','T5_paraphrased_filled_sentence_2', 
               'T5_paraphrased_filled_sentence_3']].copy()

# Using .loc to avoid SettingWithCopyWarning
capital_roberta_spacy.loc[:, 'original'] = capital_roberta['original']
capital_roberta_spacy.loc[:, 't5_0'] = capital_roberta['t5_0']
capital_roberta_spacy.loc[:, 't5_1'] = capital_roberta['t5_1']
capital_roberta_spacy.loc[:, 't5_2'] = capital_roberta['t5_2']
capital_roberta_spacy.loc[:, 't5_3'] = capital_roberta['t5_3']

# Creating a new DataFrame from 'prompt' with specified columns
citizen_roberta_spacy = prompt_citizen[['masked_sentence', 'T5_paraphrased_filled_sentence_0', 
               'T5_paraphrased_filled_sentence_1','T5_paraphrased_filled_sentence_2', 
               'T5_paraphrased_filled_sentence_3']].copy()

# Using .loc to avoid SettingWithCopyWarning
citizen_roberta_spacy.loc[:, 'original'] = citizen_roberta['original']
citizen_roberta_spacy.loc[:, 't5_0'] = citizen_roberta['t5_0']
citizen_roberta_spacy.loc[:, 't5_1'] = citizen_roberta['t5_1']
citizen_roberta_spacy.loc[:, 't5_2'] = citizen_roberta['t5_2']
citizen_roberta_spacy.loc[:, 't5_3'] = citizen_roberta['t5_3']

# Creating a new DataFrame from 'prompt' with specified columns
worksfor_roberta_spacy = prompt_worksfor[['masked_sentence', 'T5_paraphrased_filled_sentence_0', 
               'T5_paraphrased_filled_sentence_1','T5_paraphrased_filled_sentence_2', 
               'T5_paraphrased_filled_sentence_3']].copy()

# Using .loc to avoid SettingWithCopyWarning
worksfor_roberta_spacy.loc[:, 'original'] = worksfor_roberta['original']
worksfor_roberta_spacy.loc[:, 't5_0'] = worksfor_roberta['t5_0']
worksfor_roberta_spacy.loc[:, 't5_1'] = worksfor_roberta['t5_1']
worksfor_roberta_spacy.loc[:, 't5_2'] = worksfor_roberta['t5_2']
worksfor_roberta_spacy.loc[:, 't5_3'] = worksfor_roberta['t5_3']

# %%
# Exemplo de uso
# Supondo que temos um DataFrame `novo` com as colunas especificadas
masked_columns = [
    'masked_sentence', 
    'T5_paraphrased_filled_sentence_0', 
    'T5_paraphrased_filled_sentence_1',
    'T5_paraphrased_filled_sentence_2', 
    'T5_paraphrased_filled_sentence_3'
]

# As colunas que contêm os tokens originais
original_columns = [
    'original', 
    't5_0', 
    't5_1', 
    't5_2', 
    't5_3'
]

# Chamar a função para extrair tokens
bornIn_roberta_spacy = extrair_tokens_dataframe(bornIn_roberta_spacy, masked_columns, original_columns, nlp, extrair_tokens_gpe2)
diedIn_roberta_spacy = extrair_tokens_dataframe(diedIn_roberta_spacy, masked_columns, original_columns, nlp, extrair_tokens_gpe2)
capital_roberta_spacy = extrair_tokens_dataframe(capital_roberta_spacy, masked_columns, original_columns, nlp, extrair_tokens_gpe2)
citizen_roberta_spacy = extrair_tokens_dataframe(citizen_roberta_spacy, masked_columns, original_columns, nlp, extrair_tokens_gpe2)
worksfor_roberta_spacy = extrair_tokens_dataframe(worksfor_roberta_spacy, masked_columns, original_columns, nlp, extrair_tokens_org2)

# %% [markdown]
# ### Electra

# %%
bornIn_electra = pd.read_csv('D:/tese/code/data_v2/outputs/electra/outputs_bornIn_electra_v2.csv')
bornIn_electra.drop(columns=['Unnamed: 0'], inplace=True)
bornIn_electra = bornIn_electra.map(str_to_list)


diedIn_electra = pd.read_csv('D:/tese/code/data_v2/outputs/electra/outputs_diedIn_electra_v2.csv')
diedIn_electra.drop(columns=['Unnamed: 0'], inplace=True)
diedIn_electra = diedIn_electra.map(str_to_list)


capital_electra = pd.read_csv('D:/tese/code/data_v2/outputs/electra/outputs_capital_electra_v2.csv')
capital_electra.drop(columns=['Unnamed: 0'], inplace=True)
capital_electra = capital_electra.map(str_to_list)


citizen_electra = pd.read_csv('D:/tese/code/data_v2/outputs/electra/outputs_citizen_electra_v2.csv')
citizen_electra.drop(columns=['Unnamed: 0'], inplace=True)
citizen_electra = citizen_electra.map(str_to_list)


worksfor_electra = pd.read_csv('D:/tese/code/data_v2/outputs/electra/outputs_worksfor_electra_v2.csv')
worksfor_electra.drop(columns=['Unnamed: 0'], inplace=True)
worksfor_electra = worksfor_electra.map(str_to_list)

# %%
# Creating a new DataFrame from 'prompt' with specified columns
bornIn_electra_spacy = prompt_bornIn[['masked_sentence', 'T5_paraphrased_filled_sentence_0', 
               'T5_paraphrased_filled_sentence_1','T5_paraphrased_filled_sentence_2', 
               'T5_paraphrased_filled_sentence_3']].copy()

# Using .loc to avoid SettingWithCopyWarning
bornIn_electra_spacy.loc[:, 'original'] = bornIn_electra['original']
bornIn_electra_spacy.loc[:, 't5_0'] = bornIn_electra['t5_0']
bornIn_electra_spacy.loc[:, 't5_1'] = bornIn_electra['t5_1']
bornIn_electra_spacy.loc[:, 't5_2'] = bornIn_electra['t5_2']
bornIn_electra_spacy.loc[:, 't5_3'] = bornIn_electra['t5_3']

# Creating a new DataFrame from 'prompt' with specified columns
diedIn_electra_spacy = prompt_diedIn[['masked_sentence', 'T5_paraphrased_filled_sentence_0', 
               'T5_paraphrased_filled_sentence_1','T5_paraphrased_filled_sentence_2', 
               'T5_paraphrased_filled_sentence_3']].copy()

# Using .loc to avoid SettingWithCopyWarning
diedIn_electra_spacy.loc[:, 'original'] = diedIn_electra['original']
diedIn_electra_spacy.loc[:, 't5_0'] = diedIn_electra['t5_0']
diedIn_electra_spacy.loc[:, 't5_1'] = diedIn_electra['t5_1']
diedIn_electra_spacy.loc[:, 't5_2'] = diedIn_electra['t5_2']
diedIn_electra_spacy.loc[:, 't5_3'] = diedIn_electra['t5_3']

# Creating a new DataFrame from 'prompt' with specified columns
capital_electra_spacy = prompt_capital[['masked_sentence', 'T5_paraphrased_filled_sentence_0', 
               'T5_paraphrased_filled_sentence_1','T5_paraphrased_filled_sentence_2', 
               'T5_paraphrased_filled_sentence_3']].copy()

# Using .loc to avoid SettingWithCopyWarning
capital_electra_spacy.loc[:, 'original'] = capital_electra['original']
capital_electra_spacy.loc[:, 't5_0'] = capital_electra['t5_0']
capital_electra_spacy.loc[:, 't5_1'] = capital_electra['t5_1']
capital_electra_spacy.loc[:, 't5_2'] = capital_electra['t5_2']
capital_electra_spacy.loc[:, 't5_3'] = capital_electra['t5_3']

# Creating a new DataFrame from 'prompt' with specified columns
citizen_electra_spacy = prompt_citizen[['masked_sentence', 'T5_paraphrased_filled_sentence_0', 
               'T5_paraphrased_filled_sentence_1','T5_paraphrased_filled_sentence_2', 
               'T5_paraphrased_filled_sentence_3']].copy()

# Using .loc to avoid SettingWithCopyWarning
citizen_electra_spacy.loc[:, 'original'] = citizen_electra['original']
citizen_electra_spacy.loc[:, 't5_0'] = citizen_electra['t5_0']
citizen_electra_spacy.loc[:, 't5_1'] = citizen_electra['t5_1']
citizen_electra_spacy.loc[:, 't5_2'] = citizen_electra['t5_2']
citizen_electra_spacy.loc[:, 't5_3'] = citizen_electra['t5_3']

# Creating a new DataFrame from 'prompt' with specified columns
worksfor_electra_spacy = prompt_worksfor[['masked_sentence', 'T5_paraphrased_filled_sentence_0', 
               'T5_paraphrased_filled_sentence_1','T5_paraphrased_filled_sentence_2', 
               'T5_paraphrased_filled_sentence_3']].copy()

# Using .loc to avoid SettingWithCopyWarning
worksfor_electra_spacy.loc[:, 'original'] = worksfor_electra['original']
worksfor_electra_spacy.loc[:, 't5_0'] = worksfor_electra['t5_0']
worksfor_electra_spacy.loc[:, 't5_1'] = worksfor_electra['t5_1']
worksfor_electra_spacy.loc[:, 't5_2'] = worksfor_electra['t5_2']
worksfor_electra_spacy.loc[:, 't5_3'] = worksfor_electra['t5_3']

# %%
# Exemplo de uso
# Supondo que temos um DataFrame `novo` com as colunas especificadas
masked_columns = [
    'masked_sentence', 
    'T5_paraphrased_filled_sentence_0', 
    'T5_paraphrased_filled_sentence_1',
    'T5_paraphrased_filled_sentence_2', 
    'T5_paraphrased_filled_sentence_3'
]

# As colunas que contêm os tokens originais
original_columns = [
    'original', 
    't5_0', 
    't5_1', 
    't5_2', 
    't5_3'
]

# Chamar a função para extrair tokens
bornIn_electra_spacy = extrair_tokens_dataframe(bornIn_electra_spacy, masked_columns, original_columns, nlp, extrair_tokens_gpe2)
diedIn_electra_spacy = extrair_tokens_dataframe(diedIn_electra_spacy, masked_columns, original_columns, nlp, extrair_tokens_gpe2)
capital_electra_spacy = extrair_tokens_dataframe(capital_electra_spacy, masked_columns, original_columns, nlp, extrair_tokens_gpe2)
citizen_electra_spacy = extrair_tokens_dataframe(citizen_electra_spacy, masked_columns, original_columns, nlp, extrair_tokens_gpe2)
worksfor_electra_spacy = extrair_tokens_dataframe(worksfor_electra_spacy, masked_columns, original_columns, nlp, extrair_tokens_org2)

# %% [markdown]
# ## One-Shot

# %% [markdown]
# ### Bert

# %%
bornIn_bert_one = pd.read_csv('D:/tese/code/data/novos_data/dados/outputs/One_Few-Shoot/one/bert/v2/outputs_bornIn_t5_bert_one_shoot_v2.csv')\
    .drop(columns=['Unnamed: 0'])
bornIn_bert_one = bornIn_bert_one.map(str_to_list)


diedIn_bert_one = pd.read_csv('D:/tese/code/data/novos_data/dados/outputs/One_Few-Shoot/one/bert/v2/outputs_diedIn_t5_bert_one_shoot_v2.csv')\
    .drop(columns=['Unnamed: 0'])
diedIn_bert_one = diedIn_bert_one.map(str_to_list)


capital_bert_one = pd.read_csv('D:/tese/code/data/novos_data/dados/outputs/One_Few-Shoot/one/bert/v2/outputs_capital_t5_bert_one_shoot_v2.csv')\
    .drop(columns=['Unnamed: 0'])
capital_bert_one = capital_bert_one.map(str_to_list)


worksfor_bert_one = pd.read_csv('D:/tese/code/data/novos_data/dados/outputs/One_Few-Shoot/one/bert/v2/outputs_worksfor_t5_bert_one_shoot_v2.csv')\
    .drop(columns=['Unnamed: 0'])
worksfor_bert_one = worksfor_bert_one.map(str_to_list)


citizen_bert_one = pd.read_csv('D:/tese/code/data/novos_data/dados/outputs/One_Few-Shoot/one/bert/v2/outputs_citizen_t5_bert_one_shoot_v2.csv')\
    .drop(columns=['Unnamed: 0'])
citizen_bert_one = citizen_bert_one.map(str_to_list)

# %%
# Creating a new DataFrame from 'prompt' with specified columns
bornIn_bert_one_spacy = prompt_bornIn[['masked_sentence', 'T5_paraphrased_filled_sentence_0', 
               'T5_paraphrased_filled_sentence_1','T5_paraphrased_filled_sentence_2', 
               'T5_paraphrased_filled_sentence_3']].copy()

# Using .loc to avoid SettingWithCopyWarning
bornIn_bert_one_spacy.loc[:, 'original'] = bornIn_bert_one['original']
bornIn_bert_one_spacy.loc[:, 't5_0'] = bornIn_bert_one['t5_0']
bornIn_bert_one_spacy.loc[:, 't5_1'] = bornIn_bert_one['t5_1']
bornIn_bert_one_spacy.loc[:, 't5_2'] = bornIn_bert_one['t5_2']
bornIn_bert_one_spacy.loc[:, 't5_3'] = bornIn_bert_one['t5_3']

# Creating a new DataFrame from 'prompt' with specified columns
diedIn_bert_one_spacy = prompt_diedIn[['masked_sentence', 'T5_paraphrased_filled_sentence_0', 
               'T5_paraphrased_filled_sentence_1','T5_paraphrased_filled_sentence_2', 
               'T5_paraphrased_filled_sentence_3']].copy()

# Using .loc to avoid SettingWithCopyWarning
diedIn_bert_one_spacy.loc[:, 'original'] = diedIn_bert_one['original']
diedIn_bert_one_spacy.loc[:, 't5_0'] = diedIn_bert_one['t5_0']
diedIn_bert_one_spacy.loc[:, 't5_1'] = diedIn_bert_one['t5_1']
diedIn_bert_one_spacy.loc[:, 't5_2'] = diedIn_bert_one['t5_2']
diedIn_bert_one_spacy.loc[:, 't5_3'] = diedIn_bert_one['t5_3']

# Creating a new DataFrame from 'prompt' with specified columns
capital_bert_one_spacy = prompt_capital[['masked_sentence', 'T5_paraphrased_filled_sentence_0', 
               'T5_paraphrased_filled_sentence_1','T5_paraphrased_filled_sentence_2', 
               'T5_paraphrased_filled_sentence_3']].copy()

# Using .loc to avoid SettingWithCopyWarning
capital_bert_one_spacy.loc[:, 'original'] = capital_bert_one['original']
capital_bert_one_spacy.loc[:, 't5_0'] = capital_bert_one['t5_0']
capital_bert_one_spacy.loc[:, 't5_1'] = capital_bert_one['t5_1']
capital_bert_one_spacy.loc[:, 't5_2'] = capital_bert_one['t5_2']
capital_bert_one_spacy.loc[:, 't5_3'] = capital_bert_one['t5_3']

# Creating a new DataFrame from 'prompt' with specified columns
citizen_bert_one_spacy = prompt_citizen[['masked_sentence', 'T5_paraphrased_filled_sentence_0', 
               'T5_paraphrased_filled_sentence_1','T5_paraphrased_filled_sentence_2', 
               'T5_paraphrased_filled_sentence_3']].copy()

# Using .loc to avoid SettingWithCopyWarning
citizen_bert_one_spacy.loc[:, 'original'] = citizen_bert_one['original']
citizen_bert_one_spacy.loc[:, 't5_0'] = citizen_bert_one['t5_0']
citizen_bert_one_spacy.loc[:, 't5_1'] = citizen_bert_one['t5_1']
citizen_bert_one_spacy.loc[:, 't5_2'] = citizen_bert_one['t5_2']
citizen_bert_one_spacy.loc[:, 't5_3'] = citizen_bert_one['t5_3']

# Creating a new DataFrame from 'prompt' with specified columns
worksfor_bert_one_spacy = prompt_worksfor[['masked_sentence', 'T5_paraphrased_filled_sentence_0', 
               'T5_paraphrased_filled_sentence_1','T5_paraphrased_filled_sentence_2', 
               'T5_paraphrased_filled_sentence_3']].copy()

# Using .loc to avoid SettingWithCopyWarning
worksfor_bert_one_spacy.loc[:, 'original'] = worksfor_bert_one['original']
worksfor_bert_one_spacy.loc[:, 't5_0'] = worksfor_bert_one['t5_0']
worksfor_bert_one_spacy.loc[:, 't5_1'] = worksfor_bert_one['t5_1']
worksfor_bert_one_spacy.loc[:, 't5_2'] = worksfor_bert_one['t5_2']
worksfor_bert_one_spacy.loc[:, 't5_3'] = worksfor_bert_one['t5_3']

# %%
# Exemplo de uso
# Supondo que temos um DataFrame `novo` com as colunas especificadas
masked_columns = [
    'masked_sentence', 
    'T5_paraphrased_filled_sentence_0', 
    'T5_paraphrased_filled_sentence_1',
    'T5_paraphrased_filled_sentence_2', 
    'T5_paraphrased_filled_sentence_3'
]

# As colunas que contêm os tokens originais
original_columns = [
    'original', 
    't5_0', 
    't5_1', 
    't5_2', 
    't5_3'
]

# Chamar a função para extrair tokens
bornIn_bert_one_spacy = extrair_tokens_dataframe(bornIn_bert_one_spacy, masked_columns, original_columns, nlp, extrair_tokens_gpe2)
diedIn_bert_one_spacy = extrair_tokens_dataframe(diedIn_bert_one_spacy, masked_columns, original_columns, nlp, extrair_tokens_gpe2)
capital_bert_one_spacy = extrair_tokens_dataframe(capital_bert_one_spacy, masked_columns, original_columns, nlp, extrair_tokens_gpe2)
citizen_bert_one_spacy = extrair_tokens_dataframe(citizen_bert_one_spacy, masked_columns, original_columns, nlp, extrair_tokens_gpe2)
worksfor_bert_one_spacy = extrair_tokens_dataframe(worksfor_bert_one_spacy, masked_columns, original_columns, nlp, extrair_tokens_org2)

# %% [markdown]
# ### Roberta

# %%
bornIn_roberta_one = pd.read_csv('D:/tese/code/data/novos_data/dados/outputs/One_Few-Shoot/one/roberta/v2/outputs_bornIn_t5_roberta_one_shoot_v2.csv')\
    .drop(columns=['Unnamed: 0'])
bornIn_roberta_one = bornIn_roberta_one.map(str_to_list)


diedIn_roberta_one = pd.read_csv('D:/tese/code/data/novos_data/dados/outputs/One_Few-Shoot/one/roberta/v2/outputs_diedIn_t5_roberta_one_shoot_v2.csv')\
    .drop(columns=['Unnamed: 0'])
diedIn_roberta_one = diedIn_roberta_one.map(str_to_list)


capital_roberta_one = pd.read_csv('D:/tese/code/data/novos_data/dados/outputs/One_Few-Shoot/one/roberta/v2/outputs_capital_t5_roberta_one_shoot_v2.csv')\
    .drop(columns=['Unnamed: 0'])
capital_roberta_one = capital_roberta_one.map(str_to_list)


worksfor_roberta_one = pd.read_csv('D:/tese/code/data/novos_data/dados/outputs/One_Few-Shoot/one/roberta/v2/outputs_worksfor_t5_roberta_one_shoot_v2.csv')\
    .drop(columns=['Unnamed: 0'])
worksfor_roberta_one = worksfor_roberta_one.map(str_to_list)


citizen_roberta_one = pd.read_csv('D:/tese/code/data/novos_data/dados/outputs/One_Few-Shoot/one/roberta/v2/outputs_citizen_t5_roberta_one_shoot_v2.csv')\
    .drop(columns=['Unnamed: 0'])
citizen_roberta_one = citizen_roberta_one.map(str_to_list)

# %%
# Creating a new DataFrame from 'prompt' with specified columns
bornIn_roberta_one_spacy = prompt_bornIn[['masked_sentence', 'T5_paraphrased_filled_sentence_0', 
               'T5_paraphrased_filled_sentence_1','T5_paraphrased_filled_sentence_2', 
               'T5_paraphrased_filled_sentence_3']].copy()

# Using .loc to avoid SettingWithCopyWarning
bornIn_roberta_one_spacy.loc[:, 'original'] = bornIn_roberta_one['original']
bornIn_roberta_one_spacy.loc[:, 't5_0'] = bornIn_roberta_one['t5_0']
bornIn_roberta_one_spacy.loc[:, 't5_1'] = bornIn_roberta_one['t5_1']
bornIn_roberta_one_spacy.loc[:, 't5_2'] = bornIn_roberta_one['t5_2']
bornIn_roberta_one_spacy.loc[:, 't5_3'] = bornIn_roberta_one['t5_3']

# Creating a new DataFrame from 'prompt' with specified columns
diedIn_roberta_one_spacy = prompt_diedIn[['masked_sentence', 'T5_paraphrased_filled_sentence_0', 
               'T5_paraphrased_filled_sentence_1','T5_paraphrased_filled_sentence_2', 
               'T5_paraphrased_filled_sentence_3']].copy()

# Using .loc to avoid SettingWithCopyWarning
diedIn_roberta_one_spacy.loc[:, 'original'] = diedIn_roberta_one['original']
diedIn_roberta_one_spacy.loc[:, 't5_0'] = diedIn_roberta_one['t5_0']
diedIn_roberta_one_spacy.loc[:, 't5_1'] = diedIn_roberta_one['t5_1']
diedIn_roberta_one_spacy.loc[:, 't5_2'] = diedIn_roberta_one['t5_2']
diedIn_roberta_one_spacy.loc[:, 't5_3'] = diedIn_roberta_one['t5_3']

# Creating a new DataFrame from 'prompt' with specified columns
capital_roberta_one_spacy = prompt_capital[['masked_sentence', 'T5_paraphrased_filled_sentence_0', 
               'T5_paraphrased_filled_sentence_1','T5_paraphrased_filled_sentence_2', 
               'T5_paraphrased_filled_sentence_3']].copy()

# Using .loc to avoid SettingWithCopyWarning
capital_roberta_one_spacy.loc[:, 'original'] = capital_roberta_one['original']
capital_roberta_one_spacy.loc[:, 't5_0'] = capital_roberta_one['t5_0']
capital_roberta_one_spacy.loc[:, 't5_1'] = capital_roberta_one['t5_1']
capital_roberta_one_spacy.loc[:, 't5_2'] = capital_roberta_one['t5_2']
capital_roberta_one_spacy.loc[:, 't5_3'] = capital_roberta_one['t5_3']

# Creating a new DataFrame from 'prompt' with specified columns
citizen_roberta_one_spacy = prompt_citizen[['masked_sentence', 'T5_paraphrased_filled_sentence_0', 
               'T5_paraphrased_filled_sentence_1','T5_paraphrased_filled_sentence_2', 
               'T5_paraphrased_filled_sentence_3']].copy()

# Using .loc to avoid SettingWithCopyWarning
citizen_roberta_one_spacy.loc[:, 'original'] = citizen_roberta_one['original']
citizen_roberta_one_spacy.loc[:, 't5_0'] = citizen_roberta_one['t5_0']
citizen_roberta_one_spacy.loc[:, 't5_1'] = citizen_roberta_one['t5_1']
citizen_roberta_one_spacy.loc[:, 't5_2'] = citizen_roberta_one['t5_2']
citizen_roberta_one_spacy.loc[:, 't5_3'] = citizen_roberta_one['t5_3']

# Creating a new DataFrame from 'prompt' with specified columns
worksfor_roberta_one_spacy = prompt_worksfor[['masked_sentence', 'T5_paraphrased_filled_sentence_0', 
               'T5_paraphrased_filled_sentence_1','T5_paraphrased_filled_sentence_2', 
               'T5_paraphrased_filled_sentence_3']].copy()

# Using .loc to avoid SettingWithCopyWarning
worksfor_roberta_one_spacy.loc[:, 'original'] = worksfor_roberta_one['original']
worksfor_roberta_one_spacy.loc[:, 't5_0'] = worksfor_roberta_one['t5_0']
worksfor_roberta_one_spacy.loc[:, 't5_1'] = worksfor_roberta_one['t5_1']
worksfor_roberta_one_spacy.loc[:, 't5_2'] = worksfor_roberta_one['t5_2']
worksfor_roberta_one_spacy.loc[:, 't5_3'] = worksfor_roberta_one['t5_3']

# %%
# Exemplo de uso
# Supondo que temos um DataFrame `novo` com as colunas especificadas
masked_columns = [
    'masked_sentence', 
    'T5_paraphrased_filled_sentence_0', 
    'T5_paraphrased_filled_sentence_1',
    'T5_paraphrased_filled_sentence_2', 
    'T5_paraphrased_filled_sentence_3'
]

# As colunas que contêm os tokens originais
original_columns = [
    'original', 
    't5_0', 
    't5_1', 
    't5_2', 
    't5_3'
]

# Chamar a função para extrair tokens
bornIn_roberta_one_spacy = extrair_tokens_dataframe(bornIn_roberta_one_spacy, masked_columns, original_columns, nlp, extrair_tokens_gpe2)
diedIn_roberta_one_spacy = extrair_tokens_dataframe(diedIn_roberta_one_spacy, masked_columns, original_columns, nlp, extrair_tokens_gpe2)
capital_roberta_one_spacy = extrair_tokens_dataframe(capital_roberta_one_spacy, masked_columns, original_columns, nlp, extrair_tokens_gpe2)
citizen_roberta_one_spacy = extrair_tokens_dataframe(citizen_roberta_one_spacy, masked_columns, original_columns, nlp, extrair_tokens_gpe2)
worksfor_roberta_one_spacy = extrair_tokens_dataframe(worksfor_roberta_one_spacy, masked_columns, original_columns, nlp, extrair_tokens_org2)

# %% [markdown]
# ### Electra

# %%
bornIn_electra_one = pd.read_csv('D:/tese/code/data/novos_data/dados/outputs/One_Few-Shoot/one/electra/v2/outputs_bornIn_t5_electra_one_shoot_v2.csv')\
    .drop(columns=['Unnamed: 0'])
bornIn_electra_one = bornIn_electra_one.map(str_to_list)


diedIn_electra_one = pd.read_csv('D:/tese/code/data/novos_data/dados/outputs/One_Few-Shoot/one/electra/v2/outputs_diedIn_t5_electra_one_shoot_v2.csv')\
    .drop(columns=['Unnamed: 0'])
diedIn_electra_one = diedIn_electra_one.map(str_to_list)


capital_electra_one = pd.read_csv('D:/tese/code/data/novos_data/dados/outputs/One_Few-Shoot/one/electra/v2/outputs_capital_t5_electra_one_shoot_v2.csv')\
    .drop(columns=['Unnamed: 0'])
capital_electra_one = capital_electra_one.map(str_to_list)


worksfor_electra_one = pd.read_csv('D:/tese/code/data/novos_data/dados/outputs/One_Few-Shoot/one/electra/v2/outputs_worksfor_t5_electra_one_shoot_v2.csv')\
    .drop(columns=['Unnamed: 0'])
worksfor_electra_one = worksfor_electra_one.map(str_to_list)


citizen_electra_one = pd.read_csv('D:/tese/code/data/novos_data/dados/outputs/One_Few-Shoot/one/electra/v2/outputs_citizen_t5_electra_one_shoot_v2.csv')\
    .drop(columns=['Unnamed: 0'])
citizen_electra_one = citizen_electra_one.map(str_to_list)

# %%
# Creating a new DataFrame from 'prompt' with specified columns
bornIn_electra_one_spacy = prompt_bornIn[['masked_sentence', 'T5_paraphrased_filled_sentence_0', 
               'T5_paraphrased_filled_sentence_1','T5_paraphrased_filled_sentence_2', 
               'T5_paraphrased_filled_sentence_3']].copy()

# Using .loc to avoid SettingWithCopyWarning
bornIn_electra_one_spacy.loc[:, 'original'] = bornIn_electra_one['original']
bornIn_electra_one_spacy.loc[:, 't5_0'] = bornIn_electra_one['t5_0']
bornIn_electra_one_spacy.loc[:, 't5_1'] = bornIn_electra_one['t5_1']
bornIn_electra_one_spacy.loc[:, 't5_2'] = bornIn_electra_one['t5_2']
bornIn_electra_one_spacy.loc[:, 't5_3'] = bornIn_electra_one['t5_3']

# Creating a new DataFrame from 'prompt' with specified columns
diedIn_electra_one_spacy = prompt_diedIn[['masked_sentence', 'T5_paraphrased_filled_sentence_0', 
               'T5_paraphrased_filled_sentence_1','T5_paraphrased_filled_sentence_2', 
               'T5_paraphrased_filled_sentence_3']].copy()

# Using .loc to avoid SettingWithCopyWarning
diedIn_electra_one_spacy.loc[:, 'original'] = diedIn_electra_one['original']
diedIn_electra_one_spacy.loc[:, 't5_0'] = diedIn_electra_one['t5_0']
diedIn_electra_one_spacy.loc[:, 't5_1'] = diedIn_electra_one['t5_1']
diedIn_electra_one_spacy.loc[:, 't5_2'] = diedIn_electra_one['t5_2']
diedIn_electra_one_spacy.loc[:, 't5_3'] = diedIn_electra_one['t5_3']

# Creating a new DataFrame from 'prompt' with specified columns
capital_electra_one_spacy = prompt_capital[['masked_sentence', 'T5_paraphrased_filled_sentence_0', 
               'T5_paraphrased_filled_sentence_1','T5_paraphrased_filled_sentence_2', 
               'T5_paraphrased_filled_sentence_3']].copy()

# Using .loc to avoid SettingWithCopyWarning
capital_electra_one_spacy.loc[:, 'original'] = capital_electra_one['original']
capital_electra_one_spacy.loc[:, 't5_0'] = capital_electra_one['t5_0']
capital_electra_one_spacy.loc[:, 't5_1'] = capital_electra_one['t5_1']
capital_electra_one_spacy.loc[:, 't5_2'] = capital_electra_one['t5_2']
capital_electra_one_spacy.loc[:, 't5_3'] = capital_electra_one['t5_3']

# Creating a new DataFrame from 'prompt' with specified columns
citizen_electra_one_spacy = prompt_citizen[['masked_sentence', 'T5_paraphrased_filled_sentence_0', 
               'T5_paraphrased_filled_sentence_1','T5_paraphrased_filled_sentence_2', 
               'T5_paraphrased_filled_sentence_3']].copy()

# Using .loc to avoid SettingWithCopyWarning
citizen_electra_one_spacy.loc[:, 'original'] = citizen_electra_one['original']
citizen_electra_one_spacy.loc[:, 't5_0'] = citizen_electra_one['t5_0']
citizen_electra_one_spacy.loc[:, 't5_1'] = citizen_electra_one['t5_1']
citizen_electra_one_spacy.loc[:, 't5_2'] = citizen_electra_one['t5_2']
citizen_electra_one_spacy.loc[:, 't5_3'] = citizen_electra_one['t5_3']

# Creating a new DataFrame from 'prompt' with specified columns
worksfor_electra_one_spacy = prompt_worksfor[['masked_sentence', 'T5_paraphrased_filled_sentence_0', 
               'T5_paraphrased_filled_sentence_1','T5_paraphrased_filled_sentence_2', 
               'T5_paraphrased_filled_sentence_3']].copy()

# Using .loc to avoid SettingWithCopyWarning
worksfor_electra_one_spacy.loc[:, 'original'] = worksfor_electra_one['original']
worksfor_electra_one_spacy.loc[:, 't5_0'] = worksfor_electra_one['t5_0']
worksfor_electra_one_spacy.loc[:, 't5_1'] = worksfor_electra_one['t5_1']
worksfor_electra_one_spacy.loc[:, 't5_2'] = worksfor_electra_one['t5_2']
worksfor_electra_one_spacy.loc[:, 't5_3'] = worksfor_electra_one['t5_3']

# %%
# Exemplo de uso
# Supondo que temos um DataFrame `novo` com as colunas especificadas
masked_columns = [
    'masked_sentence', 
    'T5_paraphrased_filled_sentence_0', 
    'T5_paraphrased_filled_sentence_1',
    'T5_paraphrased_filled_sentence_2', 
    'T5_paraphrased_filled_sentence_3'
]

# As colunas que contêm os tokens originais
original_columns = [
    'original', 
    't5_0', 
    't5_1', 
    't5_2', 
    't5_3'
]

# Chamar a função para extrair tokens
bornIn_electra_one_spacy = extrair_tokens_dataframe(bornIn_electra_one_spacy, masked_columns, original_columns, nlp, extrair_tokens_gpe2)
diedIn_electra_one_spacy = extrair_tokens_dataframe(diedIn_electra_one_spacy, masked_columns, original_columns, nlp, extrair_tokens_gpe2)
capital_electra_one_spacy = extrair_tokens_dataframe(capital_electra_one_spacy, masked_columns, original_columns, nlp, extrair_tokens_gpe2)
citizen_electra_one_spacy = extrair_tokens_dataframe(citizen_electra_one_spacy, masked_columns, original_columns, nlp, extrair_tokens_gpe2)
worksfor_electra_one_spacy = extrair_tokens_dataframe(worksfor_electra_one_spacy, masked_columns, original_columns, nlp, extrair_tokens_org2)

# %% [markdown]
# ## Few-Shot

# %% [markdown]
# ### Bert

# %%
bornIn_bert_few = pd.read_csv('D:/tese/code/data/novos_data/dados/outputs/One_Few-Shoot/few/bert/v2/outputs_bornIn_t5_bert_few_shoot_v2.csv')\
    .drop(columns=['Unnamed: 0'])
bornIn_bert_few = bornIn_bert_few.map(str_to_list)

diedIn_bert_few = pd.read_csv('D:/tese/code/data/novos_data/dados/outputs/One_Few-Shoot/few/bert/v2/outputs_diedIn_t5_bert_few_shoot_v2.csv')\
    .drop(columns=['Unnamed: 0'])
diedIn_bert_few = diedIn_bert_few.map(str_to_list)


capital_bert_few = pd.read_csv('D:/tese/code/data/novos_data/dados/outputs/One_Few-Shoot/few/bert/v2/outputs_capital_t5_bert_few_shoot_v2.csv')\
    .drop(columns=['Unnamed: 0'])
capital_bert_few = capital_bert_few.map(str_to_list)


worksfor_bert_few = pd.read_csv('D:/tese/code/data/novos_data/dados/outputs/One_Few-Shoot/few/bert/v2/outputs_worksfor_t5_bert_few_shoot_v2.csv')\
    .drop(columns=['Unnamed: 0'])
worksfor_bert_few = worksfor_bert_few.map(str_to_list)


citizen_bert_few = pd.read_csv('D:/tese/code/data/novos_data/dados/outputs/One_Few-Shoot/few/bert/v2/outputs_citizen_t5_bert_few_shoot_v2.csv')\
    .drop(columns=['Unnamed: 0'])
citizen_bert_few = citizen_bert_few.map(str_to_list)

# %%
# Creating a new DataFrame from 'prompt' with specified columns
bornIn_bert_few_spacy = prompt_bornIn[['masked_sentence', 'T5_paraphrased_filled_sentence_0', 
               'T5_paraphrased_filled_sentence_1','T5_paraphrased_filled_sentence_2', 
               'T5_paraphrased_filled_sentence_3']].copy()

# Using .loc to avoid SettingWithCopyWarning
bornIn_bert_few_spacy.loc[:, 'original'] = bornIn_bert_few['original']
bornIn_bert_few_spacy.loc[:, 't5_0'] = bornIn_bert_few['t5_0']
bornIn_bert_few_spacy.loc[:, 't5_1'] = bornIn_bert_few['t5_1']
bornIn_bert_few_spacy.loc[:, 't5_2'] = bornIn_bert_few['t5_2']
bornIn_bert_few_spacy.loc[:, 't5_3'] = bornIn_bert_few['t5_3']

# Creating a new DataFrame from 'prompt' with specified columns
diedIn_bert_few_spacy = prompt_diedIn[['masked_sentence', 'T5_paraphrased_filled_sentence_0', 
               'T5_paraphrased_filled_sentence_1','T5_paraphrased_filled_sentence_2', 
               'T5_paraphrased_filled_sentence_3']].copy()

# Using .loc to avoid SettingWithCopyWarning
diedIn_bert_few_spacy.loc[:, 'original'] = diedIn_bert_few['original']
diedIn_bert_few_spacy.loc[:, 't5_0'] = diedIn_bert_few['t5_0']
diedIn_bert_few_spacy.loc[:, 't5_1'] = diedIn_bert_few['t5_1']
diedIn_bert_few_spacy.loc[:, 't5_2'] = diedIn_bert_few['t5_2']
diedIn_bert_few_spacy.loc[:, 't5_3'] = diedIn_bert_few['t5_3']

# Creating a new DataFrame from 'prompt' with specified columns
capital_bert_few_spacy = prompt_capital[['masked_sentence', 'T5_paraphrased_filled_sentence_0', 
               'T5_paraphrased_filled_sentence_1','T5_paraphrased_filled_sentence_2', 
               'T5_paraphrased_filled_sentence_3']].copy()

# Using .loc to avoid SettingWithCopyWarning
capital_bert_few_spacy.loc[:, 'original'] = capital_bert_few['original']
capital_bert_few_spacy.loc[:, 't5_0'] = capital_bert_few['t5_0']
capital_bert_few_spacy.loc[:, 't5_1'] = capital_bert_few['t5_1']
capital_bert_few_spacy.loc[:, 't5_2'] = capital_bert_few['t5_2']
capital_bert_few_spacy.loc[:, 't5_3'] = capital_bert_few['t5_3']

# Creating a new DataFrame from 'prompt' with specified columns
citizen_bert_few_spacy = prompt_citizen[['masked_sentence', 'T5_paraphrased_filled_sentence_0', 
               'T5_paraphrased_filled_sentence_1','T5_paraphrased_filled_sentence_2', 
               'T5_paraphrased_filled_sentence_3']].copy()

# Using .loc to avoid SettingWithCopyWarning
citizen_bert_few_spacy.loc[:, 'original'] = citizen_bert_few['original']
citizen_bert_few_spacy.loc[:, 't5_0'] = citizen_bert_few['t5_0']
citizen_bert_few_spacy.loc[:, 't5_1'] = citizen_bert_few['t5_1']
citizen_bert_few_spacy.loc[:, 't5_2'] = citizen_bert_few['t5_2']
citizen_bert_few_spacy.loc[:, 't5_3'] = citizen_bert_few['t5_3']

# Creating a new DataFrame from 'prompt' with specified columns
worksfor_bert_few_spacy = prompt_worksfor[['masked_sentence', 'T5_paraphrased_filled_sentence_0', 
               'T5_paraphrased_filled_sentence_1','T5_paraphrased_filled_sentence_2', 
               'T5_paraphrased_filled_sentence_3']].copy()

# Using .loc to avoid SettingWithCopyWarning
worksfor_bert_few_spacy.loc[:, 'original'] = worksfor_bert_few['original']
worksfor_bert_few_spacy.loc[:, 't5_0'] = worksfor_bert_few['t5_0']
worksfor_bert_few_spacy.loc[:, 't5_1'] = worksfor_bert_few['t5_1']
worksfor_bert_few_spacy.loc[:, 't5_2'] = worksfor_bert_few['t5_2']
worksfor_bert_few_spacy.loc[:, 't5_3'] = worksfor_bert_few['t5_3']

# %%
# Exemplo de uso
# Supondo que temos um DataFrame `novo` com as colunas especificadas
masked_columns = [
    'masked_sentence', 
    'T5_paraphrased_filled_sentence_0', 
    'T5_paraphrased_filled_sentence_1',
    'T5_paraphrased_filled_sentence_2', 
    'T5_paraphrased_filled_sentence_3'
]

# As colunas que contêm os tokens originais
original_columns = [
    'original', 
    't5_0', 
    't5_1', 
    't5_2', 
    't5_3'
]

# Chamar a função para extrair tokens
bornIn_bert_few_spacy = extrair_tokens_dataframe(bornIn_bert_few_spacy, masked_columns, original_columns, nlp, extrair_tokens_gpe2)
diedIn_bert_few_spacy = extrair_tokens_dataframe(diedIn_bert_few_spacy, masked_columns, original_columns, nlp, extrair_tokens_gpe2)
capital_bert_few_spacy = extrair_tokens_dataframe(capital_bert_few_spacy, masked_columns, original_columns, nlp, extrair_tokens_gpe2)
citizen_bert_few_spacy = extrair_tokens_dataframe(citizen_bert_few_spacy, masked_columns, original_columns, nlp, extrair_tokens_gpe2)
worksfor_bert_few_spacy = extrair_tokens_dataframe(worksfor_bert_few_spacy, masked_columns, original_columns, nlp, extrair_tokens_org2)

# %% [markdown]
# ### Roberta

# %%
bornIn_roberta_few = pd.read_csv('D:/tese/code/data/novos_data/dados/outputs/One_Few-Shoot/few/roberta/v2/outputs_bornIn_t5_roberta_few_shoot_v2.csv')\
    .drop(columns=['Unnamed: 0'])
bornIn_roberta_few = bornIn_roberta_few.map(str_to_list)


diedIn_roberta_few = pd.read_csv('D:/tese/code/data/novos_data/dados/outputs/One_Few-Shoot/few/roberta/v2/outputs_diedIn_t5_roberta_few_shoot_v2.csv')\
    .drop(columns=['Unnamed: 0'])
diedIn_roberta_few = diedIn_roberta_few.map(str_to_list)


capital_roberta_few = pd.read_csv('D:/tese/code/data/novos_data/dados/outputs/One_Few-Shoot/few/roberta/v2/outputs_capital_t5_roberta_few_shoot_v2.csv')\
    .drop(columns=['Unnamed: 0'])
capital_roberta_few = capital_roberta_few.map(str_to_list)


worksfor_roberta_few = pd.read_csv('D:/tese/code/data/novos_data/dados/outputs/One_Few-Shoot/few/roberta/v2/outputs_worksfor_t5_roberta_few_shoot_v2.csv')\
    .drop(columns=['Unnamed: 0'])
worksfor_roberta_few = worksfor_roberta_few.map(str_to_list)


citizen_roberta_few = pd.read_csv('D:/tese/code/data/novos_data/dados/outputs/One_Few-Shoot/few/roberta/v2/outputs_citizen_t5_roberta_few_shoot_v2.csv')\
    .drop(columns=['Unnamed: 0'])
citizen_roberta_few = citizen_roberta_few.map(str_to_list)

# %%
# Creating a new DataFrame from 'prompt' with specified columns
bornIn_roberta_few_spacy = prompt_bornIn[['masked_sentence', 'T5_paraphrased_filled_sentence_0', 
               'T5_paraphrased_filled_sentence_1','T5_paraphrased_filled_sentence_2', 
               'T5_paraphrased_filled_sentence_3']].copy()

# Using .loc to avoid SettingWithCopyWarning
bornIn_roberta_few_spacy.loc[:, 'original'] = bornIn_roberta_few['original']
bornIn_roberta_few_spacy.loc[:, 't5_0'] = bornIn_roberta_few['t5_0']
bornIn_roberta_few_spacy.loc[:, 't5_1'] = bornIn_roberta_few['t5_1']
bornIn_roberta_few_spacy.loc[:, 't5_2'] = bornIn_roberta_few['t5_2']
bornIn_roberta_few_spacy.loc[:, 't5_3'] = bornIn_roberta_few['t5_3']

# Creating a new DataFrame from 'prompt' with specified columns
diedIn_roberta_few_spacy = prompt_diedIn[['masked_sentence', 'T5_paraphrased_filled_sentence_0', 
               'T5_paraphrased_filled_sentence_1','T5_paraphrased_filled_sentence_2', 
               'T5_paraphrased_filled_sentence_3']].copy()

# Using .loc to avoid SettingWithCopyWarning
diedIn_roberta_few_spacy.loc[:, 'original'] = diedIn_roberta_few['original']
diedIn_roberta_few_spacy.loc[:, 't5_0'] = diedIn_roberta_few['t5_0']
diedIn_roberta_few_spacy.loc[:, 't5_1'] = diedIn_roberta_few['t5_1']
diedIn_roberta_few_spacy.loc[:, 't5_2'] = diedIn_roberta_few['t5_2']
diedIn_roberta_few_spacy.loc[:, 't5_3'] = diedIn_roberta_few['t5_3']

# Creating a new DataFrame from 'prompt' with specified columns
capital_roberta_few_spacy = prompt_capital[['masked_sentence', 'T5_paraphrased_filled_sentence_0', 
               'T5_paraphrased_filled_sentence_1','T5_paraphrased_filled_sentence_2', 
               'T5_paraphrased_filled_sentence_3']].copy()

# Using .loc to avoid SettingWithCopyWarning
capital_roberta_few_spacy.loc[:, 'original'] = capital_roberta_few['original']
capital_roberta_few_spacy.loc[:, 't5_0'] = capital_roberta_few['t5_0']
capital_roberta_few_spacy.loc[:, 't5_1'] = capital_roberta_few['t5_1']
capital_roberta_few_spacy.loc[:, 't5_2'] = capital_roberta_few['t5_2']
capital_roberta_few_spacy.loc[:, 't5_3'] = capital_roberta_few['t5_3']

# Creating a new DataFrame from 'prompt' with specified columns
citizen_roberta_few_spacy = prompt_citizen[['masked_sentence', 'T5_paraphrased_filled_sentence_0', 
               'T5_paraphrased_filled_sentence_1','T5_paraphrased_filled_sentence_2', 
               'T5_paraphrased_filled_sentence_3']].copy()

# Using .loc to avoid SettingWithCopyWarning
citizen_roberta_few_spacy.loc[:, 'original'] = citizen_roberta_few['original']
citizen_roberta_few_spacy.loc[:, 't5_0'] = citizen_roberta_few['t5_0']
citizen_roberta_few_spacy.loc[:, 't5_1'] = citizen_roberta_few['t5_1']
citizen_roberta_few_spacy.loc[:, 't5_2'] = citizen_roberta_few['t5_2']
citizen_roberta_few_spacy.loc[:, 't5_3'] = citizen_roberta_few['t5_3']

# Creating a new DataFrame from 'prompt' with specified columns
worksfor_roberta_few_spacy = prompt_worksfor[['masked_sentence', 'T5_paraphrased_filled_sentence_0', 
               'T5_paraphrased_filled_sentence_1','T5_paraphrased_filled_sentence_2', 
               'T5_paraphrased_filled_sentence_3']].copy()

# Using .loc to avoid SettingWithCopyWarning
worksfor_roberta_few_spacy.loc[:, 'original'] = worksfor_roberta_few['original']
worksfor_roberta_few_spacy.loc[:, 't5_0'] = worksfor_roberta_few['t5_0']
worksfor_roberta_few_spacy.loc[:, 't5_1'] = worksfor_roberta_few['t5_1']
worksfor_roberta_few_spacy.loc[:, 't5_2'] = worksfor_roberta_few['t5_2']
worksfor_roberta_few_spacy.loc[:, 't5_3'] = worksfor_roberta_few['t5_3']

# %%
# Exemplo de uso
# Supondo que temos um DataFrame `novo` com as colunas especificadas
masked_columns = [
    'masked_sentence', 
    'T5_paraphrased_filled_sentence_0', 
    'T5_paraphrased_filled_sentence_1',
    'T5_paraphrased_filled_sentence_2', 
    'T5_paraphrased_filled_sentence_3'
]

# As colunas que contêm os tokens originais
original_columns = [
    'original', 
    't5_0', 
    't5_1', 
    't5_2', 
    't5_3'
]

# Chamar a função para extrair tokens
bornIn_roberta_few_spacy = extrair_tokens_dataframe(bornIn_roberta_few_spacy, masked_columns, original_columns, nlp, extrair_tokens_gpe2)
diedIn_roberta_few_spacy = extrair_tokens_dataframe(diedIn_roberta_few_spacy, masked_columns, original_columns, nlp, extrair_tokens_gpe2)
capital_roberta_few_spacy = extrair_tokens_dataframe(capital_roberta_few_spacy, masked_columns, original_columns, nlp, extrair_tokens_gpe2)
citizen_roberta_few_spacy = extrair_tokens_dataframe(citizen_roberta_few_spacy, masked_columns, original_columns, nlp, extrair_tokens_gpe2)
worksfor_roberta_few_spacy = extrair_tokens_dataframe(worksfor_roberta_few_spacy, masked_columns, original_columns, nlp, extrair_tokens_org2)

# %% [markdown]
# ### Electra

# %%
bornIn_electra_few = pd.read_csv('D:/tese/code/data/novos_data/dados/outputs/One_Few-Shoot/few/electra/v2/outputs_bornIn_t5_electra_few_shoot_v2.csv')\
    .drop(columns=['Unnamed: 0'])
bornIn_electra_few = bornIn_electra_few.map(str_to_list)


diedIn_electra_few = pd.read_csv('D:/tese/code/data/novos_data/dados/outputs/One_Few-Shoot/few/electra/v2/outputs_diedIn_t5_electra_few_shoot_v2.csv')\
    .drop(columns=['Unnamed: 0'])
diedIn_electra_few = diedIn_electra_few.map(str_to_list)


capital_electra_few = pd.read_csv('D:/tese/code/data/novos_data/dados/outputs/One_Few-Shoot/few/electra/v2/outputs_capital_t5_electra_few_shoot_v2.csv')\
    .drop(columns=['Unnamed: 0'])
capital_electra_few = capital_electra_few.map(str_to_list)


worksfor_electra_few = pd.read_csv('D:/tese/code/data/novos_data/dados/outputs/One_Few-Shoot/few/electra/v2/outputs_worksfor_t5_electra_few_shoot_v2.csv')\
    .drop(columns=['Unnamed: 0'])
worksfor_electra_few = worksfor_electra_few.map(str_to_list)


citizen_electra_few = pd.read_csv('D:/tese/code/data/novos_data/dados/outputs/One_Few-Shoot/few/electra/v2/outputs_citizen_t5_electra_few_shoot_v2.csv')\
    .drop(columns=['Unnamed: 0'])
citizen_electra_few = citizen_electra_few.map(str_to_list)

# %%
# Creating a new DataFrame from 'prompt' with specified columns
bornIn_electra_few_spacy = prompt_bornIn[['masked_sentence', 'T5_paraphrased_filled_sentence_0', 
               'T5_paraphrased_filled_sentence_1','T5_paraphrased_filled_sentence_2', 
               'T5_paraphrased_filled_sentence_3']].copy()

# Using .loc to avoid SettingWithCopyWarning
bornIn_electra_few_spacy.loc[:, 'original'] = bornIn_electra_few['original']
bornIn_electra_few_spacy.loc[:, 't5_0'] = bornIn_electra_few['t5_0']
bornIn_electra_few_spacy.loc[:, 't5_1'] = bornIn_electra_few['t5_1']
bornIn_electra_few_spacy.loc[:, 't5_2'] = bornIn_electra_few['t5_2']
bornIn_electra_few_spacy.loc[:, 't5_3'] = bornIn_electra_few['t5_3']

# Creating a new DataFrame from 'prompt' with specified columns
diedIn_electra_few_spacy = prompt_diedIn[['masked_sentence', 'T5_paraphrased_filled_sentence_0', 
               'T5_paraphrased_filled_sentence_1','T5_paraphrased_filled_sentence_2', 
               'T5_paraphrased_filled_sentence_3']].copy()

# Using .loc to avoid SettingWithCopyWarning
diedIn_electra_few_spacy.loc[:, 'original'] = diedIn_electra_few['original']
diedIn_electra_few_spacy.loc[:, 't5_0'] = diedIn_electra_few['t5_0']
diedIn_electra_few_spacy.loc[:, 't5_1'] = diedIn_electra_few['t5_1']
diedIn_electra_few_spacy.loc[:, 't5_2'] = diedIn_electra_few['t5_2']
diedIn_electra_few_spacy.loc[:, 't5_3'] = diedIn_electra_few['t5_3']

# Creating a new DataFrame from 'prompt' with specified columns
capital_electra_few_spacy = prompt_capital[['masked_sentence', 'T5_paraphrased_filled_sentence_0', 
               'T5_paraphrased_filled_sentence_1','T5_paraphrased_filled_sentence_2', 
               'T5_paraphrased_filled_sentence_3']].copy()

# Using .loc to avoid SettingWithCopyWarning
capital_electra_few_spacy.loc[:, 'original'] = capital_electra_few['original']
capital_electra_few_spacy.loc[:, 't5_0'] = capital_electra_few['t5_0']
capital_electra_few_spacy.loc[:, 't5_1'] = capital_electra_few['t5_1']
capital_electra_few_spacy.loc[:, 't5_2'] = capital_electra_few['t5_2']
capital_electra_few_spacy.loc[:, 't5_3'] = capital_electra_few['t5_3']

# Creating a new DataFrame from 'prompt' with specified columns
citizen_electra_few_spacy = prompt_citizen[['masked_sentence', 'T5_paraphrased_filled_sentence_0', 
               'T5_paraphrased_filled_sentence_1','T5_paraphrased_filled_sentence_2', 
               'T5_paraphrased_filled_sentence_3']].copy()

# Using .loc to avoid SettingWithCopyWarning
citizen_electra_few_spacy.loc[:, 'original'] = citizen_electra_few['original']
citizen_electra_few_spacy.loc[:, 't5_0'] = citizen_electra_few['t5_0']
citizen_electra_few_spacy.loc[:, 't5_1'] = citizen_electra_few['t5_1']
citizen_electra_few_spacy.loc[:, 't5_2'] = citizen_electra_few['t5_2']
citizen_electra_few_spacy.loc[:, 't5_3'] = citizen_electra_few['t5_3']

# Creating a new DataFrame from 'prompt' with specified columns
worksfor_electra_few_spacy = prompt_worksfor[['masked_sentence', 'T5_paraphrased_filled_sentence_0', 
               'T5_paraphrased_filled_sentence_1','T5_paraphrased_filled_sentence_2', 
               'T5_paraphrased_filled_sentence_3']].copy()

# Using .loc to avoid SettingWithCopyWarning
worksfor_electra_few_spacy.loc[:, 'original'] = worksfor_electra_few['original']
worksfor_electra_few_spacy.loc[:, 't5_0'] = worksfor_electra_few['t5_0']
worksfor_electra_few_spacy.loc[:, 't5_1'] = worksfor_electra_few['t5_1']
worksfor_electra_few_spacy.loc[:, 't5_2'] = worksfor_electra_few['t5_2']
worksfor_electra_few_spacy.loc[:, 't5_3'] = worksfor_electra_few['t5_3']

# %%
# Exemplo de uso
# Supondo que temos um DataFrame `novo` com as colunas especificadas
masked_columns = [
    'masked_sentence', 
    'T5_paraphrased_filled_sentence_0', 
    'T5_paraphrased_filled_sentence_1',
    'T5_paraphrased_filled_sentence_2', 
    'T5_paraphrased_filled_sentence_3'
]

# As colunas que contêm os tokens originais
original_columns = [
    'original', 
    't5_0', 
    't5_1', 
    't5_2', 
    't5_3'
]

# Chamar a função para extrair tokens
bornIn_electra_few_spacy = extrair_tokens_dataframe(bornIn_electra_few_spacy, masked_columns, original_columns, nlp, extrair_tokens_gpe2)
diedIn_electra_few_spacy = extrair_tokens_dataframe(diedIn_electra_few_spacy, masked_columns, original_columns, nlp, extrair_tokens_gpe2)
capital_electra_few_spacy = extrair_tokens_dataframe(capital_electra_few_spacy, masked_columns, original_columns, nlp, extrair_tokens_gpe2)
citizen_electra_few_spacy = extrair_tokens_dataframe(citizen_electra_few_spacy, masked_columns, original_columns, nlp, extrair_tokens_gpe2)
worksfor_electra_few_spacy = extrair_tokens_dataframe(worksfor_electra_few_spacy, masked_columns, original_columns, nlp, extrair_tokens_org2)
